# %% [markdown]
# #  Save Novels with Emotions
#
# DS 5001 Text as Data

# %% [markdown]
# **Purpose:** Collect all the novel collections we have and combine each novel with the combined sentiment lexicon table we created last time.

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_dir = f"{data_home}/syuzhet"

# %%
config = {
    'novels': {
        'OHCO': 'book_id chap_id para_num sent_num token_num'.split(),
        'LIB': 'LIB',
        'TOKENS': 'CORPUS',
        'data_dir': f"{data_home}/novels"
    },
    'austen-melville': {
        'OHCO': 'book_id chap_id para_num sent_num token_num'.split(),
        'LIB': 'LIB',
        'TOKENS': 'CORPUS',
        'data_dir': f"{output_dir}"
    }
}

# %%
token_cols = ['pos','term_str']
salex_csv = f'{data_home}/lexicons/salex_combo.csv'

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ## Get Lexicons
#
# We created this last week.

# %%
SALEX = pd.read_csv(salex_csv).set_index('term_str')
SALEX['nrc_polarity'] = SALEX.nrc_positive - SALEX.nrc_negative

# %%
SALEX.columns.tolist()
# Out:
# ['nrc_anger',
#  'nrc_anticipation',
#  'nrc_disgust',
#  'nrc_fear',
#  'nrc_joy',
#  'nrc_negative',
#  'nrc_positive',
#  'nrc_sadness',
#  'nrc_surprise',
#  'nrc_trust',
#  'nrc_sentiment',
#  'bing_negative',
#  'bing_positive',
#  'bing_sentiment',
#  'syu_sentiment',
#  'gi_sentiment',
#  'nrc_polarity']

# %% [markdown]
# ## Get Texts
#
# We import two sets of pre-processed novels and combine them.

# %%
TOKENS = {} # Dict of dataframes
LIB = {} # Dict of dataframes
for prefix in config:
    print(prefix)
    token_file = f"{config[prefix]['data_dir']}/{prefix}-{config[prefix]['TOKENS']}.csv"
    TOKENS[prefix] = pd.read_csv(token_file).set_index(config[prefix]['OHCO'])[token_cols]    
    lib_file = f"{config[prefix]['data_dir']}/{prefix}-{config[prefix]['LIB']}.csv"
    LIB[prefix] = pd.read_csv(lib_file)
# Out:
# novels
# austen-melville

# %% [markdown]
# ## Standardize `TOKENS` tables

# %% [markdown]
# We make the OHCO columns names the same (since one has `chap_num` and the other `chap_id`).

# %%
TOKENS['novels'].index.names = config['austen-melville']['OHCO']

# %%
TOKENS['novels']
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy
# ...                                                  ...          ...
# baskervilles    11      114      1        7          RBR         more
#                                           8           JJ  comfortable
#                                           9           IN      outside
#                                           10          IN         than
#                                           11          NN           in
#
# [1500417 rows x 2 columns]

# %% [markdown]
# ## Standardize `LIB` tables

# %%
LIB['austen-melville']['author_id'] = LIB['austen-melville'].author.str.split(', ').str[0].str.lower()

# %%
LIB['novels'].columns = ['book_id', 'genre', 'author_id']

# %%
LIB['novels']['title'] = LIB['novels']['book_id']
LIB['novels'] = LIB['novels'].set_index('book_id')

# %%
LIB['novels'] = LIB['novels'][['author_id', 'title']]
LIB['novels']['corpus'] = 'novels'

# %%
LIB['novels']
# Out:
#                  author_id            title  corpus
# book_id
# secretadversary   christie  secretadversary  novels
# styles            christie           styles  novels
# moonstone          collins        moonstone  novels
# adventures           doyle       adventures  novels
# baskervilles         doyle     baskervilles  novels
# scarlet              doyle          scarlet  novels
# signoffour           doyle       signoffour  novels
# marieroget             poe       marieroget  novels
# ruemorgue              poe        ruemorgue  novels
# northangerabbey     austen  northangerabbey  novels
# christmascarole    dickens  christmascarole  novels
# monk                 lewis             monk  novels
# pitandpendulum         poe   pitandpendulum  novels
# reddeath               poe         reddeath  novels
# usher                  poe            usher  novels
# udolpho          radcliffe          udolpho  novels
# oldenglishbaron      reeve  oldenglishbaron  novels
# frankenstein       shelley     frankenstein  novels
# dracula             stoker          dracula  novels
# castleofotranto    walpole  castleofotranto  novels

# %%
LIB['austen-melville'] = LIB['austen-melville'].set_index('book_id')
LIB['austen-melville'] = LIB['austen-melville'][['author_id', 'title']]
LIB['austen-melville']['corpus'] = 'austen-melville'

# %%
LIB['austen-melville']
# Out:
#         author_id                                              title  \
# book_id
# 105        austen                                         PERSUASION
# 121        austen                                   NORTHANGER ABBEY
# 141        austen                                     MANSFIELD PARK
# 158        austen                                               EMMA
# 161        austen                              SENSE AND SENSIBILITY
# 946        austen                                         LADY SUSAN
# 1212       austen                            LOVE AND FREINDSHIP SIC
# 1342       austen                                PRIDE AND PREJUDICE
# 1900     melville                  TYPEE A ROMANCE OF THE SOUTH SEAS
# 2701     melville                             MOBY DICK OR THE WHALE
# 4045     melville                  OMOO ADVENTURES IN THE SOUTH SEAS
# 8118     melville  REDBURN HIS FIRST VOYAGE BEING THE SAILOR BOY ...
# 10712    melville          WHITE JACKET OR THE WORLD ON A MAN OF WAR
# 13720    melville                   MARDI AND A VOYAGE THITHER VOL I
# 13721    melville                  MARDI AND A VOYAGE THITHER VOL II
# 15422    melville             ISRAEL POTTER HIS FIFTY YEARS OF EXILE
# 15859    melville                                   THE PIAZZA TALES
# 21816    melville                  THE CONFIDENCE MAN HIS MASQUERADE
# 34970    melville                          PIERRE OR THE AMBIGUITIES
#
#                   corpus
# book_id
# 105      austen-melville
# 121      austen-melville
# 141      austen-melville
# 158      austen-melville
# 161      austen-melville
# 946      austen-melville
# 1212     austen-melville
# 1342     austen-melville
# 1900     austen-melville
# 2701     austen-melville
# 4045     austen-melville
# 8118     austen-melville
# 10712    austen-melville
# 13720    austen-melville
# 13721    austen-melville
# 15422    austen-melville
# 15859    austen-melville
# 21816    austen-melville
# 34970    austen-melville

# %% [markdown]
# ## Fix indexes

# %% [markdown]
# Before combining things, convert integer indexes into strings.

# %%
LIB['austen-melville'].index = [str(i) for i in LIB['austen-melville'].index]

# %%
tmp = TOKENS['austen-melville'].reset_index()
tmp.book_id = tmp.book_id.astype(str)
TOKENS['austen-melville'] = tmp.set_index(config['austen-melville']['OHCO'])

# %%
# TOKENS['austen-melville'].loc['105']

# %% [markdown]
# ## Combine LIBs

# %%
LIB['austen-melville'].index = [str(i) for i in LIB['austen-melville'].index]

# %%
LIB_ALL = pd.concat(LIB.values())

# %%
LIB_ALL.sample(10)
# Out:
#            author_id                                              title  \
# 8118        melville  REDBURN HIS FIRST VOYAGE BEING THE SAILOR BOY ...
# 1342          austen                                PRIDE AND PREJUDICE
# udolpho    radcliffe                                            udolpho
# dracula       stoker                                            dracula
# 121           austen                                   NORTHANGER ABBEY
# ruemorgue        poe                                          ruemorgue
# 105           austen                                         PERSUASION
# scarlet        doyle                                            scarlet
# 15859       melville                                   THE PIAZZA TALES
# 141           austen                                     MANSFIELD PARK
#
#                     corpus
# 8118       austen-melville
# 1342       austen-melville
# udolpho             novels
# dracula             novels
# 121        austen-melville
# ruemorgue           novels
# 105        austen-melville
# scarlet             novels
# 15859      austen-melville
# 141        austen-melville

# %% [markdown]
# ## Combine TOKENS

# %%
TOKENS_ALL = pd.concat(TOKENS.values())

# %%
TOKENS_ALL
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy
# ...                                                  ...          ...
# 34970           114     24       0        6           DT          the
#                                           7          NNP  ambiguities
#                                           8           IN           by
#                                           9          NNP       herman
#                                           10         NNP     melville
#
# [3559689 rows x 2 columns]

# %% [markdown]
# # Join TOKENS and SALEX

# %%
TOKENS_ALL_SALEX = TOKENS_ALL.join(SALEX, on='term_str')

# %%
TOKENS_ALL_SALEX.head()
# Out:
#                                                      pos     term_str  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy
#
#                                                     term_str_padded  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                    the
#                                           1                  young
#                                           2            adventurers
#                                           3                    ltd
#                         1        0        0                  tommy
#
#                                                      nrc_anger  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                NaN
#                                           1                0.0
#                                           2                NaN
#                                           3                NaN
#                         1        0        0                NaN
#
#                                                      nrc_anticipation  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                       NaN
#                                           1                       1.0
#                                           2                       NaN
#                                           3                       NaN
#                         1        0        0                       NaN
#
#                                                      nrc_disgust  nrc_fear  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                  NaN       NaN
#                                           1                  0.0       0.0
#                                           2                  NaN       NaN
#                                           3                  NaN       NaN
#                         1        0        0                  NaN       NaN
#
#                                                      nrc_joy  nrc_negative  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0              NaN           NaN
#                                           1              1.0           0.0
#                                           2              NaN           NaN
#                                           3              NaN           NaN
#                         1        0        0              NaN           NaN
#
#                                                      nrc_positive  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                   NaN
#                                           1                   1.0
#                                           2                   NaN
#                                           3                   NaN
#                         1        0        0                   NaN
#
#                                                      nrc_sadness  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                  NaN
#                                           1                  0.0
#                                           2                  NaN
#                                           3                  NaN
#                         1        0        0                  NaN
#
#                                                      nrc_surprise  nrc_trust  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                   NaN        NaN
#                                           1                   1.0        0.0
#                                           2                   NaN        NaN
#                                           3                   NaN        NaN
#                         1        0        0                   NaN        NaN
#
#                                                      nrc_sentiment  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                    NaN
#                                           1                    1.0
#                                           2                    NaN
#                                           3                    NaN
#                         1        0        0                    NaN
#
#                                                      bing_negative  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                    NaN
#                                           1                    NaN
#                                           2                    NaN
#                                           3                    NaN
#                         1        0        0                    NaN
#
#                                                      bing_positive  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                    NaN
#                                           1                    NaN
#                                           2                    NaN
#                                           3                    NaN
#                         1        0        0                    NaN
#
#                                                      bing_sentiment  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                     NaN
#                                           1                     NaN
#                                           2                     NaN
#                                           3                     NaN
#                         1        0        0                     NaN
#
#                                                      syu_sentiment  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                    NaN
#                                           1                    0.4
#                                           2                    NaN
#                                           3                    NaN
#                         1        0        0                    NaN
#
#                                                      gi_sentiment  \
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                   NaN
#                                           1                   NaN
#                                           2                   NaN
#                                           3                   NaN
#                         1        0        0                   NaN
#
#                                                      nrc_polarity
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0                   NaN
#                                           1                   1.0
#                                           2                   NaN
#                                           3                   NaN
#                         1        0        0                   NaN

# %% [markdown]
# # Compute Sentiments
#
# > Syuzhet computes the sentiment of a sentence by summing the sentiment scores of all the words in the sentence and then dividing by the total number of words in the sentence.

# %%
OHCO = list(TOKENS_ALL_SALEX.index.names)

# %%
OHCO
# Out:
# ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']

# %%
def get_sentiments(bag:int = 3, aggs=['mean']):
    DOCS = TOKENS_ALL_SALEX.groupby(OHCO[:bag]).agg(
        {
            'term_str': ['count'],
            'nrc_sentiment': aggs,
            'bing_sentiment': aggs,
            'syu_sentiment': aggs,
            'gi_sentiment': aggs
        }
    )
    DOCS.columns = DOCS.columns.droplevel(1)
    DOCS = DOCS.iloc[:,1:] # Drop term_str col
    DOCS = DOCS.fillna(0)
    return DOCS

# %%
SENTS = get_sentiments(4)
PARAS = get_sentiments(3)
CHAPS = get_sentiments(2)

# %%
CHAPS
# Out:
#                  nrc_sentiment  bing_sentiment  syu_sentiment  gi_sentiment
# book_id chap_id
# 105     1             0.368421        0.152542       0.214462      0.407035
#         2             0.400000        0.228571       0.217658      0.329897
#         3             0.553922        0.267081       0.246494      0.317597
#         4             0.204082        0.205128       0.171033      0.318919
#         5             0.263415        0.241667       0.226024      0.366102
# ...                        ...             ...            ...           ...
# udolpho 54           -0.050710       -0.177305      -0.021992      0.129293
#         55           -0.193277       -0.325581      -0.076154     -0.017143
#         56           -0.004587       -0.118182       0.016324      0.172414
#         57            0.522222        0.414634       0.266906      0.453488
# usher   1            -0.200750       -0.297030      -0.097087     -0.075710
#
# [1505 rows x 4 columns]

# %%
CHAPS.loc['105'].nrc_sentiment.plot(figsize=(10,2));

# %% [markdown]
# # Visualize
#
# We can look at sentiment signals by book, bag, and lexon.

# %%
def visualize_sentiment(book_id, bag_df, lexicon, kind='line'):
    return bag_df.loc[str(book_id), lexicon + '_sentiment'].plot(figsize=(20,4), kind=kind);

# %% [markdown]
# ## Persuasion, Sentence, Syuzhet

# %%
visualize_sentiment('105', SENTS, 'syu');

# %% [markdown]
# ## Persuasion, Paragraph, Syuzhet

# %%
visualize_sentiment('105', PARAS, 'syu');

# %% [markdown]
# ## Persuasion, Chapter, Syuzhet

# %%
visualize_sentiment('105', CHAPS, 'syu');

# %% [markdown]
# ## Persuasion, Chapter, NRC

# %%
visualize_sentiment('105', CHAPS, 'nrc');

# %% [markdown]
# ## Persuasion, Chapter, Bing

# %%
visualize_sentiment('105', CHAPS, 'bing');

# %%
visualize_sentiment('105', CHAPS, 'bing', kind='bar');

# %% [markdown]
# ## Dracula, Chapter, Bing

# %%
visualize_sentiment('dracula', CHAPS, 'bing');

# %% [markdown]
# # Correlate

# %%
CHAPS.corr().style.format(precision=2).background_gradient(cmap="YlGnBu", axis=None)
# Out:
# <style type="text/css">
# #T_0e5d5_row0_col0, #T_0e5d5_row1_col1, #T_0e5d5_row2_col2, #T_0e5d5_row3_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_0e5d5_row0_col1, #T_0e5d5_row1_col0 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_0e5d5_row0_col2, #T_0e5d5_row2_col0 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_0e5d5_row0_col3, #T_0e5d5_row3_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_0e5d5_row1_col2, #T_0e5d5_row2_col1 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_0e5d5_row1_col3, #T_0e5d5_row3_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_0e5d5_row2_col3, #T_0e5d5_row3_col2 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# </style>
# <table id="T_0e5d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e5d5_level0_col0" class="col_heading level0 col0" >nrc_sentiment</th>
#       <th id="T_0e5d5_level0_col1" class="col_heading level0 col1" >bing_sentiment</th>
#       <th id="T_0e5d5_level0_col2" class="col_heading level0 col2" >syu_sentiment</th>
#       <th id="T_0e5d5_level0_col3" class="col_heading level0 col3" >gi_sentiment</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e5d5_level0_row0" class="row_heading level0 row0" >nrc_sentiment</th>
#       <td id="T_0e5d5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_0e5d5_row0_col1" class="data row0 col1" >0.70</td>
#       <td id="T_0e5d5_row0_col2" class="data row0 col2" >0.81</td>
#       <td id="T_0e5d5_row0_col3" class="data row0 col3" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_0e5d5_level0_row1" class="row_heading level0 row1" >bing_sentiment</th>
#       <td id="T_0e5d5_row1_col0" class="data row1 col0" >0.70</td>
#       <td id="T_0e5d5_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_0e5d5_row1_col2" class="data row1 col2" >0.81</td>
#       <td id="T_0e5d5_row1_col3" class="data row1 col3" >0.68</td>
#     </tr>
#     <tr>
#       <th id="T_0e5d5_level0_row2" class="row_heading level0 row2" >syu_sentiment</th>
#       <td id="T_0e5d5_row2_col0" class="data row2 col0" >0.81</td>
#       <td id="T_0e5d5_row2_col1" class="data row2 col1" >0.81</td>
#       <td id="T_0e5d5_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_0e5d5_row2_col3" class="data row2 col3" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_0e5d5_level0_row3" class="row_heading level0 row3" >gi_sentiment</th>
#       <td id="T_0e5d5_row3_col0" class="data row3 col0" >0.67</td>
#       <td id="T_0e5d5_row3_col1" class="data row3 col1" >0.68</td>
#       <td id="T_0e5d5_row3_col2" class="data row3 col2" >0.72</td>
#       <td id="T_0e5d5_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
CHAPS.loc['105'].plot.bar(figsize=(20,5), rot=0);

# %% [markdown]
# # Save

# %%
LIB_ALL.to_csv(f"{output_dir}/combo-LIB.csv")
TOKENS_ALL.to_csv(f"{output_dir}/combo-TOKENS.csv")

# %% [markdown]
# We pickle our sentiment data for speed.

# %%
data_dir
# Out:
# '/sfs/gpfs/tardis/home/rca2t/Documents/MSDS/DS5001/DS5001-2025-01-R/data/syuzhet'

# %%
SENTS.to_pickle(f"{data_dir}/M_SENTS.pickle")
CHAPS.to_pickle(f"{data_dir}/M_CHAPS.pickle")
PARAS.to_pickle(f"{data_dir}/M_PARAS.pickle")

# %% [markdown]
# Save as sentences for R package.

# %%
TOKENS_ALL['term_str_padded'] = TOKENS_ALL.term_str + " "
SENTENCES = TOKENS_ALL.groupby(['book_id','chap_id','para_num','sent_num']).term_str_padded.sum().to_frame('sent_str')
SENTENCES.to_csv(f"{output_dir}/combo-SENTENCES.csv")
