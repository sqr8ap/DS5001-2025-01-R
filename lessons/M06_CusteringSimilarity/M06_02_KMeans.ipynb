# %% [markdown]
# # KMeans from Scratch
#
# ```yaml
# Course:   DS 5001
# Module:   06 Lab
# Topic:    KMeans Clustering
# Author:   R.C.Alvarado
# Date:     21 February 2024
# ```

# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()

# %%
from string import ascii_uppercase as letters
from scipy.spatial.distance import pdist

# %% [markdown]
# # Prepare

# %% [markdown]
# ## Get Data IRIS

# %%
IRIS = sns.load_dataset('iris')
IRIS.index.name = 'obs_id'

# %%
IRIS.head()
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# obs_id
# 0                5.1          3.5           1.4          0.2  setosa
# 1                4.9          3.0           1.4          0.2  setosa
# 2                4.7          3.2           1.3          0.2  setosa
# 3                4.6          3.1           1.5          0.2  setosa
# 4                5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(IRIS, hue='species');

# %% [markdown]
# ## Extract SPECIES

# %%
SPECIES = IRIS.groupby('species').mean()

# %%
SPECIES.style.background_gradient()
# Out:
# <style type="text/css">
# #T_23c75_row0_col0, #T_23c75_row0_col2, #T_23c75_row0_col3, #T_23c75_row1_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_23c75_row0_col1, #T_23c75_row2_col0, #T_23c75_row2_col2, #T_23c75_row2_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_23c75_row1_col0 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_23c75_row1_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_23c75_row1_col3 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_23c75_row2_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# </style>
# <table id="T_23c75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23c75_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_23c75_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_23c75_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_23c75_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23c75_level0_row0" class="row_heading level0 row0" >setosa</th>
#       <td id="T_23c75_row0_col0" class="data row0 col0" >5.006000</td>
#       <td id="T_23c75_row0_col1" class="data row0 col1" >3.428000</td>
#       <td id="T_23c75_row0_col2" class="data row0 col2" >1.462000</td>
#       <td id="T_23c75_row0_col3" class="data row0 col3" >0.246000</td>
#     </tr>
#     <tr>
#       <th id="T_23c75_level0_row1" class="row_heading level0 row1" >versicolor</th>
#       <td id="T_23c75_row1_col0" class="data row1 col0" >5.936000</td>
#       <td id="T_23c75_row1_col1" class="data row1 col1" >2.770000</td>
#       <td id="T_23c75_row1_col2" class="data row1 col2" >4.260000</td>
#       <td id="T_23c75_row1_col3" class="data row1 col3" >1.326000</td>
#     </tr>
#     <tr>
#       <th id="T_23c75_level0_row2" class="row_heading level0 row2" >virginica</th>
#       <td id="T_23c75_row2_col0" class="data row2 col0" >6.588000</td>
#       <td id="T_23c75_row2_col1" class="data row2 col1" >2.974000</td>
#       <td id="T_23c75_row2_col2" class="data row2 col2" >5.552000</td>
#       <td id="T_23c75_row2_col3" class="data row2 col3" >2.026000</td>
#     </tr>
#   </tbody>
# </table>

# %%
SPECIES.plot.barh();

# %%
IRIS2 = IRIS.iloc[:,:-1] # Remove the labels

# %% [markdown]
# # Implement
#
# We implement K-Means clustering using Pandas.

# %%
def KMeans(X, k=2, d_metric='euclidean', max_iterations=100):
    
    # Randomly pick k centroids from the data
    CENTROIDS = X.sample(k)
    CENTROIDS.index.name = 'cat_id'
    CENTROIDS.index = list(letters)[:k] # Give them alphabetic names

    # Create table to store distances from centroids using a cartesian product
    combos = pd.MultiIndex.from_product([CENTROIDS.index, X.index])
    DISTANCES = pd.DataFrame({'dist': None}, index=combos)
    DISTANCES.index.names = ['cat_id', 'obs_id']

    # Iterate until convergence
    progress = [] # Save states for visualization later
    for i in range(max_iterations):

        # Get distances
        DISTANCES['dist'] = DISTANCES.apply(lambda x: 
            pdist(pd.concat([CENTROIDS.loc[x.name[0]], X.loc[x.name[1]]], axis=1).T, d_metric)[0], 
            axis=1)

        # Get min distances
        CLUSTERS = DISTANCES.unstack().idxmin().to_frame('cat')
        CLUSTERS.index = CLUSTERS.index.droplevel(0)

        # Get new centroids
        NEW_CENTROIDS = X.join(CLUSTERS).groupby('cat').mean()   

        # Test for convergence
        t = abs((CENTROIDS - NEW_CENTROIDS).sum().sum())
        progress.append(t) # Capture progress
        if t == 0:
            break            

        # Update centroids for next iteration
        CENTROIDS = NEW_CENTROIDS
            
    return X.join(CLUSTERS), progress

# %% [markdown]
# Use entropy to evaluate results.

# %%
def evaluate(result, label_df, label_name='species'):
    
    # Combine results with labels
    X = result.join(label_df[label_name])
    
    # Get results per category in a confusion matrix
    M = X.value_counts(['cat', label_name])\
        .sort_index().to_frame().unstack(fill_value=0)
    M.columns = M.columns.droplevel(0)
    
    # Get entropy per category
    MP = (M.T + .0001) / (M.T + .0001).sum()
    MI = -np.log2(MP)
    MH = (MP * MI).sum()
    MH = np.round(MH, 2).sort_values()
    
    # Get redundancy as performance measure
    MR = np.round(1 - MH.mean() / np.log2(k), 2)
    
    return M, MH, MR

# %% [markdown]
# # Test

# %%
k = 3
max_iterations = 10
d_metric = 'jensenshannon'
# d_metric = 'canberra'
# d_metric = 'cityblock'
# d_metric = 'euclidean'
# d_metric = 'jaccard'

# %%
R, progress = KMeans(IRIS2, k, d_metric, max_iterations)
M, H, G = evaluate(R, IRIS, 'species')

# %%
pd.Series(progress).plot.bar(title=f"{d_metric} R={G}", rot=0, figsize=(5,2))
pd.Series(progress).plot.line(style='o-', figsize=(5,2), color='orange');

# %%
M.T
# Out:
# cat          A   B   C
# species
# setosa       0  50   0
# versicolor  46   0   4
# virginica    3   0  47

# %%
pd.concat([M.T.idxmax(), H], axis=1, keys=['prediction', 'entropy'])
# Out:
#      prediction  entropy
# cat
# A    versicolor     0.33
# B        setosa     0.00
# C     virginica     0.40

# %%
print('Grade:', G)
# Out:
# Grade: 0.85

# %% [markdown]
# # Visualize

# %%
sns.pairplot(R, hue='cat');

# %% [markdown]
# # Appendix

# %% [markdown]
# ![image.png](attachment:8aee8feb-1c0f-49be-9e4a-c3ebfe04a023.png)
# [Source](https://www.wikiwand.com/en/Canberra_distance)
