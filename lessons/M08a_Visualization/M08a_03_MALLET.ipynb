# %% [markdown]
# # Using MALLET
#
# DS 5001 Text as Data

# %% [markdown]
# ## Getting MALLET on Your System
#
# [Download MALLET](https://github.com/mimno/Mallet/zipball/master) here. This will download a zip archive file.
#
# For other options, check out the [home page](https://mimno.github.io/Mallet/).
#
# Once downloaded, you will find an executable in the `/bin` directory of the folder created when unzipping the archive file.
#
# You can just now run MALLET in a variety of ways:
#
# - You can just run the `mallet` binary file by its full path.\
#   `/home/rca2t/Documents/MSDS/DS5001/mimno-Mallet-5fbf800/bin/mallet`
# - You create a symbolic link of the binary to somewhere convenient on your system and call the link.\
#   e.g. `ln -s mimno-Mallet-5fbf800/bin/mallet mallet`
# - You can run `ant` and build and install it on your system.\
#   See Appendix below information on how compile <a href="https://mimno.github.io/Mallet/topics">MALLET</a> if you are so inclined.

# %% [markdown]
# For Mallet to run properly:
#
# - Have Java JDK and Ant installed.
#   - `module load java/8`
#   - `module load ant`
# - Put JAVA_HOME and ANT_HOME in environment.
#   - `export JAVA_HOME = "<location_of_java_root_dir>"`
#   - `export ANT_HOME = "<location_of_ant_binary>"`
# - Download and unarchive MALLET in suitable directory.
# - Put MALLET_HOME in environment.
#   - `export MALLET_HOME = "<location_of_mallet_roor_dir>"`
# - Run `ant` in MALLET directory.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_prefix = 'novels'

# %%
mallet_data = f"{output_dir}/mallet-demo"
# !mkdir {mallet_data}
# Out:
# mkdir: cannot create directory ‘/sfs/gpfs/tardis/home/rca2t/Documents/MSDS/DS5001/DS5001-2025-01-R/output/mallet-demo’: File exists

# %%
OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']

# %%
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100

# %% [markdown]
# ### Import

# %%
import pandas as pd
# import numpy as np # Not needed today

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Import a CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# ### Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# ### Dump corpus to CSV file

# %%
mallet_corpus = DOC.join(LIB)[['doc_str','author_id']]
mallet_corpus.columns = 'doc_content doc_label'.split()
mallet_corpus[['doc_label','doc_content']].to_csv(f'{mallet_data}/novels-corpus.csv', index=False)

# %%
mallet_corpus
# Out:
#                                                           doc_content  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     doc_label
# book_id    chap_id
# adventures 1            doyle
#            2            doyle
#            3            doyle
#            4            doyle
#            5            doyle
# ...                       ...
# udolpho    54       radcliffe
#            55       radcliffe
#            56       radcliffe
#            57       radcliffe
# usher      1              poe
#
# [320 rows x 2 columns]

# %%
# !more {mallet_data}/novels-corpus.csv

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
# mallet_home = "/home/rca2t/Documents/MSDS/DS5001/mimno-Mallet-5fbf800/bin"
mallet = config['DEFAULT']['mallet_binary']
mallet
# Out:
# '/home/rca2t/opt/mallet/bin/mallet'

# %%
# ! {mallet_home}/mallet

# %% [markdown]
# ### Import corpus
#
# This converts the `.csv` file we just created into a `.mallet` file.
#
# This file has a format that MALLET can more effectively process.
#
# Here we pass all of our arguments as command line arguments.
#
# Note there is an option to put this arguments into file and just pass the file as an argument.

# %%
# !{mallet} import-file \
--input {mallet_data}/novels-corpus.csv \
--output {mallet_data}/novels-corpus.mallet \
--keep-sequence TRUE

# %% [markdown]
# ### Train topics
#
# Now we generate our model with a bunch of paramaters.
#
# - `num-topics`: Number of topics to generate.
# - `num-iterations`: The number of iterations to run.
# - `output-doc-topics`: The file to dump our doc-topic data (THETA)
# - `output-topic-keys`: The file to dump our topic keys.
# - `word-topic-counts-file`: The file to dump our word-topic counts (raw PHI)
# - `topic-word-weights-file`: The file to dump our topic-word weights (PHI)
# - `xml-topic-report`: The XML file to dump a report.
# - `xml-topic-phrase-report`: The XML file to dump the phrases associated with topics.
# - `show-topics-interval`: The iteration interval to show results during model fitting.
# - `use-symmetric-alpha`: Whether or not to use the same alpha value for each topic.
# - `optimize-interval`: The optimization interval.
# - `diagnostics-file`: The XML file to dump some diagnostic information.

# %%
# !{mallet} train-topics \
--input {mallet_data}/novels-corpus.mallet \
--num-topics {num_topics} \
--num-iterations {num_iters} \
--output-doc-topics {mallet_data}/novels-doc-topics.txt \
--output-topic-keys {mallet_data}/novels-topic-keys.txt \
--word-topic-counts-file {mallet_data}/novels-word-topic-counts-file.txt \
--topic-word-weights-file {mallet_data}/novels-topic-word-weights-file.txt \
--xml-topic-report {mallet_data}/novels-topic-report.xml \
--xml-topic-phrase-report {mallet_data}/novels-topic-phrase-report.xml \
--show-topics-interval {show_interval} \
--use-symmetric-alpha false  \
--optimize-interval 100 \
--diagnostics-file {mallet_data}/novels-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 15717
# total tokens: 1164070
# <10> LL/token: -9.09352
# <20> LL/token: -8.60192
# <30> LL/token: -8.42725
# <40> LL/token: -8.32408
# <50> LL/token: -8.24761
# <60> LL/token: -8.18959
# <70> LL/token: -8.14445
# <80> LL/token: -8.11114
# <90> LL/token: -8.08777
#
# 0	0.25	the and that for with sergeant miss franklin out when this had rachel which have diamond betteredge what was him
# 1	0.25	the was and but been were had not would two who one there room very this that about from small
# 2	0.25	the and was were they their which for had could more not with all them only that from even first
# 3	0.25	the and his was had there with him down they that said out but for all were could upon sir
# 4	0.25	her she had and was for herself could with not all more would when might from moment but left very
# 5	0.25	the and that had from was its into among these with one over when air all this mind dark mountains
# 6	0.25	the not manfred said thou this and with project isabella gutenberg thy matilda for theodore will thee lord work from
# 7	0.25	the and that was all there for when out must went one have them back came door time night room
# 8	0.25	and but that not your had when this which from for heart yet our one was have life should father
# 9	0.25	the and emily but montoni was said that they now count which who then heard annette this for castle them
# 10	0.25	the and tuppence was tommy but that mrs sir his you poirot dont said with out yes julius they about
# 11	0.25	and the for his that with not but him all may our which then shall are when this van have
# 12	0.25	the and with which upon his now their aubert some while still every they world voice eyes followed how seemed
# 13	0.25	you that have said your will what not him are this his can but know has then would see for
# 14	0.25	and not very for with but they catherine miss mrs all such never well quite are was dear good any
# 15	0.25	the his and had was that house with which may from him own made one under man words question three
# 16	0.25	the that his and not which with him this had for have valancourt been would from madame own when who
# 17	0.25	the that which upon have holmes and this with been from some has for our there now are case into
# 18	0.25	and the his him lord sir said they with for edmund will shall all them but that baron your their
# 19	0.25	the his her was him upon from with that for and this shall your agnes antonia she himself hand them
#
# <100> LL/token: -8.05849
# <110> LL/token: -8.03647
# <120> LL/token: -8.02078
# <130> LL/token: -8.00805
# <140> LL/token: -7.99458
# <150> LL/token: -7.98335
# <160> LL/token: -7.97387
# <170> LL/token: -7.96587
# <180> LL/token: -7.95634
# <190> LL/token: -7.94878
#
# 0	0.25	the and with for miss sergeant franklin out this rachel when diamond which betteredge lady way have back blake looked
# 1	0.25	the was not been but one and this were two with would there who about found had having point for
# 2	0.25	the was they and were their for that this all had them could have more which only first been these
# 3	0.25	and the his was had with said him they upon which down there for that but sir were our man
# 4	0.25	her she and had was could herself for from that all been not than but would with more heart might
# 5	0.25	the and that from over among its had where long into night mountains then one trees are through sea little
# 6	0.25	the manfred said his thou this not project isabella gutenberg thy and matilda with for theodore your lord but thee
# 7	0.25	the and was all there when out that came for door night from but now time room have back them
# 8	0.25	and but when had not that was from our your which myself for father those heart life yet every death
# 9	0.25	the and emily but montoni was that said they had count then now this annette heard who for which she
# 10	0.25	the tuppence tommy and was but mrs poirot that sir you with said dont julius they his yes inglethorp him
# 11	0.25	and the that not his for with him all our but are van which may helsing then when shall lucy
# 12	0.25	the and with which his upon was were now while seemed aubert some into voice whose through every still eyes
# 13	0.25	you that have said not will what your him are for this can with know has would then but one
# 14	0.25	and not very catherine miss but with for mrs they the was never dear such tilney all being good well
# 15	0.25	the his had and that was which from house him with after own man left might made three morning question
# 16	0.25	the his and that with not which him had for this when from valancourt madame much whom would was who
# 17	0.25	the and which upon that holmes have this has with from been are some little case now very for our
# 18	0.25	and the his him lord sir said they edmund will with baron your all for upon them shall but philip
# 19	0.25	the his her him upon was from your that for this agnes antonia and ambrosio shall himself them then till
#
# <200> LL/token: -7.93956
# <210> LL/token: -7.93532
# <220> LL/token: -7.93122
# <230> LL/token: -7.92657
# <240> LL/token: -7.92177
# <250> LL/token: -7.92263
# <260> LL/token: -7.9156
# <270> LL/token: -7.9151
# <280> LL/token: -7.91426
# <290> LL/token: -7.91556
#
# 0	0.25	the and with miss sergeant franklin this rachel out when for which diamond betteredge have lady said about what way
# 1	0.25	the not was been but this one there would and that two were with its having about being very found
# 2	0.25	the was for were their and they have had more all them this could from only that with first its
# 3	0.25	the and his was with him had said upon but they man were down there sir which our for face
# 4	0.25	her she and had was for not herself could all that but than been with more might heart would moment
# 5	0.25	the and that from over with aubert its among mountains sun after where along light mind one had long woods
# 6	0.25	the manfred said thou and his not this project isabella gutenberg thy matilda with but theodore lord from hippolita thee
# 7	0.25	the and was that there all had out when for from one them came see night door back room now
# 8	0.25	and but that when not had was myself our which yet your those from father death heart life one who
# 9	0.25	the and emily but that montoni she they said was had then count who this annette now heard till from
# 10	0.25	tuppence tommy the was but mrs you poirot sir said his dont julius they yes him with inglethorp about out
# 11	0.25	and the his not that with him for all but which are our when van may helsing shall must lucy
# 12	0.25	the and with which his upon was into while were voice seemed now every some how they world whose length
# 13	0.25	you that have said not will your what are for him this with can but know would has then how
# 14	0.25	and not very catherine but miss they mrs with for tilney such could must brother much henry general would dear
# 15	0.25	the and his had that was which from house him with after man might own who made himself question left
# 16	0.25	the his and that which with him not had was from this when for valancourt madame would whom much been
# 17	0.25	the upon holmes which and have that has are from very this with our been all now some case into
# 18	0.25	and the his lord him sir said edmund they will your baron all shall with them upon for philip but
# 19	0.25	the his him upon from her your was this agnes antonia that with for ambrosio lorenzo himself then matilda till
#
# [beta: 0.01775]
# <300> LL/token: -7.90603
# <310> LL/token: -7.91145
# <320> LL/token: -7.90733
# <330> LL/token: -7.90553
# <340> LL/token: -7.90556
# <350> LL/token: -7.90423
# <360> LL/token: -7.89871
# <370> LL/token: -7.89732
# <380> LL/token: -7.89602
# <390> LL/token: -7.89326
#
# 0	0.16422	the and miss sergeant franklin this rachel when with diamond which betteredge out said had lady blake him own cuff
# 1	0.34065	the that not this been but was there one its very about having two would evidence without found body these
# 2	0.36389	the and was for were their that had they have from with all them this more could some not only
# 3	0.26409	the and his was but him said had upon man that sir with they down which there this were our
# 4	0.34088	her she and had was but not for with herself could all the been than more might after heart when
# 5	0.26279	the and with that they aubert from over mountains woods among sun where little after scene road sea along light
# 6	0.10929	the manfred said thou not and isabella project gutenberg his thy this matilda theodore thee with lord hippolita princess but
# 7	0.36315	the and was that there had all for out when with from one came were them room night door way
# 8	0.30041	and but that when had not was myself father life heart yet saw your which this from death are eyes
# 9	0.1682	the emily and she that but montoni was said this had they count annette then heard who castle now from
# 10	0.15904	tuppence the tommy but was you poirot mrs said sir his they julius dont inglethorp yes him about know she
# 11	0.17066	and his not him that all but for the when are van our helsing shall which may lucy like with
# 12	0.30453	the and which with his upon was into now while seemed voice were how those its still length yet through
# 13	0.3802	you that have not said your will what for but are him this with can would know and has how
# 14	0.21595	and not catherine very they miss but mrs tilney with such being for general any isabella much morland thorpe henry
# 15	0.34717	the and his was that had which house him from after with man time question three day words who himself
# 16	0.28216	the and his that which had him with was when from not valancourt for this much now madame countenance upon
# 17	0.18142	the and holmes which upon have has with very from are that our been his some now little case this
# 18	0.17817	and the his lord sir him said edmund your will they baron with philip shall but them all for upon
# 19	0.15489	his the him your from upon was with that this antonia agnes her ambrosio himself lorenzo then matilda till for
#
# [beta: 0.02087]
# <400> LL/token: -7.89275
# <410> LL/token: -7.88432
# <420> LL/token: -7.88011
# <430> LL/token: -7.87587
# <440> LL/token: -7.874
# <450> LL/token: -7.87111
# <460> LL/token: -7.86782
# <470> LL/token: -7.86579
# <480> LL/token: -7.86512
# <490> LL/token: -7.86294
#
# 0	0.11514	the had miss sergeant franklin and rachel which this diamond betteredge when said him lady with out say blake about
# 1	0.35767	the been this not upon that but evidence there its which has body very about murder these corpse will now
# 2	0.46122	the and was that with for were had have from they their not this who them which been could more
# 3	0.25549	and his the him upon sir but they said was man which its down there had scrooge very about old
# 4	0.4106	her she and was had not but for herself could more all with been that than might from after when
# 5	0.23805	the and they with aubert that from their woods among over mountains where its little after along sun into light
# 6	0.05606	the manfred said his thou isabella gutenberg project not matilda thy lord this theodore with and hippolita princess thee prince
# 7	0.46104	the and was that there had with out for all were one from have could came then room back been
# 8	0.31159	and but when had that yet your father life myself not which heart was our night saw every did towards
# 9	0.12469	the emily and she that montoni but said had they count was annette this from then heard who castle now
# 10	0.10922	tuppence the tommy but was you poirot mrs sir his said julius dont they yes inglethorp about she well know
# 11	0.12374	and his not all him but when for that our shall van helsing may which are must lucy like though
# 12	0.34828	the and which his with but upon was now into while door this voice seemed were these through every light
# 13	0.49377	you that have not said your will and for what this him but are with his can know would has
# 14	0.1712	and not catherine very they but miss mrs tilney could such for being isabella them morland thorpe general there allen
# 15	0.41508	the his and was that had which from him house after man with three london little day without morning question
# 16	0.29547	the his and which had that with him was when for valancourt now this upon not whom from himself would
# 17	0.1326	holmes which upon and his that our the very little down have been has watson from sherlock had this however
# 18	0.13501	and the his lord him sir said edmund they baron will your but philip them upon their shall with oswald
# 19	0.09936	his the him your from with upon and antonia was agnes ambrosio lorenzo that himself matilda till you hand bosom
#
# [beta: 0.02246]
# <500> LL/token: -7.86361
# <510> LL/token: -7.85979
# <520> LL/token: -7.85996
# <530> LL/token: -7.85407
# <540> LL/token: -7.85153
# <550> LL/token: -7.84624
# <560> LL/token: -7.84275
# <570> LL/token: -7.84057
# <580> LL/token: -7.84086
# <590> LL/token: -7.83568
#
# 0	0.08836	the and had miss sergeant franklin which rachel diamond when betteredge lady this time what said have again blake cuff
# 1	0.27157	the have that upon been this not but which its there body has are very evidence will from about one
# 2	0.55306	the and was that with had for were not from their this they who have some all one them more
# 3	0.23381	his and upon sir him said scrooge its but down man they which old very moor were henry our there
# 4	0.46229	her she and was had for not herself but with would when after from been more too lady all than
# 5	0.20565	the and they with aubert that their woods from over mountains among little light whose after along where sun were
# 6	0.03714	the manfred said thou his isabella gutenberg project matilda this thy not theodore lord but hippolita princess thee prince with
# 7	0.54801	the and was that there had with out for from all one could were them came room been back see
# 8	0.29152	and but when which that myself yet father your did life eyes ever every saw towards heart feelings our also
# 9	0.09417	the emily she and that montoni said had but count was annette this now who castle from when they then
# 10	0.07966	tuppence tommy but you poirot mrs said sir his was julius dont she inglethorp yes about well not down him
# 11	0.09568	and his not for him all but when our shall van are which helsing must may lucy like then now
# 12	0.38679	the and which his but upon now this then with door into seemed while voice through was those heard yet
# 13	0.59583	you that have and not said your will him this for but what are with know his can would has
# 14	0.12974	catherine not very and they miss but could tilney mrs such being isabella general morland thorpe allen been henry must
# 15	0.45807	the his that was and which had him been house after man london from himself question may day morning three
# 16	0.3056	the his and which that had him with when now been but from himself upon heart whom tears not much
# hich upon our and very down have but little man two has sherlock however well now then this
# 18	0.10544	and the his lord sir him said edmund your will baron they philip them upon shall father oswald son lovel
# 19	0.06539	his your the him upon from with antonia agnes ambrosio lorenzo himself matilda till without hand bosom every them don
#
# [beta: 0.0233]
# <600> LL/token: -7.83307
# <610> LL/token: -7.83133
# <620> LL/token: -7.82796
# <630> LL/token: -7.82845
# <640> LL/token: -7.82438
# <650> LL/token: -7.82584
# <660> LL/token: -7.8218
# <670> LL/token: -7.8227
# <680> LL/token: -7.82101
# <690> LL/token: -7.81921
#
# 0	0.07208	the and had miss sergeant franklin which rachel diamond when betteredge with this lady own time about blake cuff house
# 1	0.18694	the have upon been this not which that very its will there body has now about evidence but are any
# 2	0.64202	the and was that had with for from not were this their they but who all have some more one
# 3	0.1963	his and sir upon scrooge him its moor henry said which down very baskerville about old like man christmas ghost
# 4	0.49769	her she and was had for not herself with more than would been after too but what when moment into
# 5	0.18076	the and with they aubert that their woods now which over where mountains from them after blanche among light along
# 6	0.02804	the manfred said thou isabella gutenberg project matilda thy not his this theodore lord hippolita princess thee prince cried work
# 7	0.61687	the and was that there with had out for from were one all said could room been when they came
# 8	0.26241	and but when myself which life yet father had every night your felt did towards eyes feelings miserable also ever
# 9	0.07663	the emily she and that montoni said had but valancourt count annette was madame who this they then from castle
# 10	0.06522	tuppence tommy but you was poirot mrs his sir julius dont inglethorp about yes not she know said like down
# 11	0.07862	and his not all him for when that our van helsing are shall may which now then lucy like must
# 12	0.41422	the and which his upon but this with now still door voice heard then him while seemed through yet were
# 13	0.68139	you that have and not him your will for said what this are but his can know with all has
# 14	0.09754	not catherine very they and miss mrs tilney could but general such being isabella them morland thorpe much allen henry
# 15	0.47314	the his that was which him been man had london after house morning day case name left since three next
# 16	0.3193	the his and which with that him had when from been but upon himself heart now whom how then could
# 17	0.08652	his holmes which upon and very our down have had man has then about sherlock little would however well but
# 18	0.08525	and the his lord sir said him edmund baron will they your philip upon them oswald shall lovel son father
# 19	0.0512	his the your upon from with him antonia agnes ambrosio lorenzo matilda himself you till bosom without hand them that
#
# [beta: 0.02385]
# <700> LL/token: -7.82066
# <710> LL/token: -7.81558
# <720> LL/token: -7.81724
# <730> LL/token: -7.8145
# <740> LL/token: -7.81513
# <750> LL/token: -7.81822
# <760> LL/token: -7.81469
# <770> LL/token: -7.81275
# <780> LL/token: -7.81027
# <790> LL/token: -7.81209
#
# 0	0.06419	the and had miss sergeant franklin which rachel diamond betteredge about his time own sir blake when again lady cuff
# 1	0.13109	the upon have been not this its which there that body very has will any corpse thus marie one madame
# 2	0.72679	the and was that had with for from not were this but their they have some who all more would
# 3	0.13274	his upon sir scrooge and its moor henry said which him down man baskerville like dont spirit christmas ghost about
# 4	0.51774	her she was and had not with for herself more all than been too moment after when might lady could
# 5	0.16605	the and with they aubert which his their from that among woods its over light mountains now where blanche little
# 6	0.02168	the manfred said thou his isabella gutenberg project thy matilda not lord theodore this hippolita princess thee prince from your
# 7	0.66798	the and was that with had there out for from could all one were been when they him came room
# 8	0.23378	and when but myself life yet which your father did towards eyes night saw even feelings miserable man elizabeth ever
# 9	0.0675	the emily she and that montoni said had valancourt but was count from annette who then madame now this when
# 10	0.05917	tuppence tommy you his but poirot mrs sir julius was dont about yes inglethorp she know its said then like
# 11	0.07167	and his not all for when our him van but that helsing shall may then which lucy like are now
# 12	0.43548	the and which his but upon this now door still heard then its seemed yet every light with through voice
# 13	0.7522	you that have and not said your will what this him for are but his with can know would has
# 14	0.08076	catherine not very and they miss tilney mrs could but isabella general morland such thorpe them being though for allen
# 15	0.47386	the his that was which been had him house london day after man might case name three little morning one
# 16	0.33637	the his and which that him had with when been from himself for heart while upon whom now tears love
# 17	0.0835	his holmes which upon our very down have and man about has had would now sherlock little however then but
# 18	0.07333	and his the lord sir him said edmund baron they your will philip them upon oswald lovel with all shall
# 19	0.04217	his the upon your with him from antonia ambrosio lorenzo agnes matilda himself till bosom every myself don though convent
#
# [beta: 0.02407]
# <800> LL/token: -7.80969
# <810> LL/token: -7.81029
# <820> LL/token: -7.80798
# <830> LL/token: -7.80669
# <840> LL/token: -7.80437
# <850> LL/token: -7.80434
# <860> LL/token: -7.80154
# <870> LL/token: -7.80312
# <880> LL/token: -7.80119
# <890> LL/token: -7.80091
#
# 0	0.06225	the had and miss franklin sergeant his rachel which diamond betteredge when time own lady this again blake say cuff
# 1	0.09572	the upon have been this its which not there that body has will corpse about are marie any now very
# 2	0.80132	the and was that had with for not from this were their they have but all some who more would
# 3	0.09108	his upon and sir scrooge its him moor henry which baskerville very said christmas ghost spirit they dont mortimer stapleton
# 4	0.52785	her she and was had for with herself not after been all too might moment made lady when seemed more
# 5	0.15961	the and with they aubert their woods mountains now where among that over its upon were whose which sun along
# 6	0.01954	the said manfred his thou isabella gutenberg project thy matilda lord theodore not hippolita this princess prince work thee castle
# 7	0.70792	the and was that had there with out him from one could were all they said came room for when
# 8	0.21138	and but when myself which life your our towards yet feelings father every miserable elizabeth saw death eyes heart day
# 9	0.06364	the emily she and that montoni had said was but valancourt from they annette madame who count this when now
# 10	0.05605	tuppence you tommy his but poirot mrs sir dont julius about inglethorp said was yes not what know did like
# 11	0.06528	and his not for all when but our van helsing shall that which may are then like him must lucy
# 12	0.44647	the and which his but door now this upon then heard its while voice light still into through yet with
# 13	0.8099	you that and have not your will for what said this but are him with know can has would all
# 14	0.06995	not catherine very they miss tilney mrs could but such general isabella morland thorpe though being allen henry their every
# 15	0.46473	the his that which was had been house day morning london may very one man might case after also most
# 16	0.35276	the his and which him that had with when but from himself heart upon while tears father now love then
# 17	0.0809	his holmes upon which our very little had man about sherlock has would and have however said small then watson
# 18	0.06525	and the his lord him said sir edmund they baron will philip your them upon oswald shall lovel son father
# 19	0.0361	the his upon your him from with antonia agnes ambrosio lorenzo matilda bosom every you till himself hand don myself
#
# [beta: 0.02428]
# <900> LL/token: -7.8002
# <910> LL/token: -7.80138
# <920> LL/token: -7.79843
# <930> LL/token: -7.79769
# <940> LL/token: -7.80053
# <950> LL/token: -7.79797
# <960> LL/token: -7.79849
# <970> LL/token: -7.797
# <980> LL/token: -7.79833
# <990> LL/token: -7.79454
#
# 0	0.05683	the had miss his franklin sergeant which and rachel diamond betteredge when time out what this say sir blake way
# 1	0.07363	the upon have been this not its which there very about any are body found corpse marie one will now
# 2	0.8659	the and was that with had for from this were not their they who which have but some all would
# 3	0.07026	his sir scrooge upon and its moor henry him said very baskerville which christmas spirit ghost man mortimer stapleton good
# 4	0.531	her she was and had for not with herself been more after would too moment lady than all seemed again
# 5	0.15837	the and with they aubert their which that woods over were mountains light its among now upon sun where blanche
# 6	0.01837	the manfred said thou his isabella gutenberg project matilda thy not lord theodore this hippolita princess your thee prince work
# 7	0.73895	the and was that had there with out for from one all said could were him they them when came
# 8	0.1878	and but when myself which yet life feelings even our father saw did man miserable again elizabeth thus ever mind
# 9	0.06252	the emily and that she had montoni said but valancourt was from who annette count this madame when they castle
# 10	0.0527	tuppence you tommy his but was poirot mrs sir julius dont inglethorp not yes about its miss like did know
# 11	0.05968	and his not all for when our van him helsing that but may are shall like which lucy must her
# 12	0.45436	the and his which but upon this door heard then now its through light voice seemed still were while more
# 13	0.85778	you that and have not your what will said but this for are him with know can would all has
# 14	0.06389	not catherine very they miss tilney but mrs and could general such isabella thorpe morland being though allen their henry
# 15	0.45505	the his that which been was case has him house day man had london morning name matter may after made
# 16	0.37259	his the and which him had with that when but from now heart upon himself been still while love then
# 17	0.07881	his which holmes upon our very have and little however sherlock then watson has man small about from this should
# 18	0.05777	his and the lord him sir said edmund baron will they your philip them upon oswald lovel shall son their
# 19	0.03311	his the your upon him from with antonia agnes ambrosio lorenzo matilda you till bosom out every myself though don
#
# [beta: 0.02451]
# <1000> LL/token: -7.79692
#
# Total time: 1 minutes 52 seconds

# %% [markdown]
# # Inspect Results

# %%
# !ls -l {mallet_data}
# Out:
# total 30121
# -rw------- 1 rca2t users  7960141 Mar 20 14:24 novels-corpus.csv
# -rw------- 1 rca2t users  4998651 Mar 20 14:24 novels-corpus.mallet
# -rw------- 1 rca2t users    92188 Mar 20 14:26 novels-diagnostics.xml
# -rw------- 1 rca2t users   138623 Mar 20 14:26 novels-doc-topics.txt
# -rw------- 1 rca2t users     2368 Mar 20 14:26 novels-topic-keys.txt
# -rw------- 1 rca2t users    58616 Mar 20 14:26 novels-topic-phrase-report.xml
# -rw------- 1 rca2t users    19999 Mar 20 14:26 novels-topic-report.xml
# -rw------- 1 rca2t users 16896437 Mar 20 14:26 novels-topic-word-weights-file.txt
# -rw------- 1 rca2t users   640529 Mar 20 14:26 novels-word-topic-counts-file.txt

# %% [markdown]
# ## Appendix
#
# ### Mallet
#
# Website: https://mimno.github.io/Mallet/
#
# MALLET is a Java-based package for statistical natural language processing, document classification, clustering, topic modeling, information extraction, and other machine learning applications to text.
#
# MALLET includes sophisticated tools for document classification: efficient routines for converting text to "features", a wide variety of algorithms (including Naïve Bayes, Maximum Entropy, and Decision Trees), and code for evaluating classifier performance using several commonly used metrics.
#
# In addition to classification, MALLET includes tools for sequence tagging for applications such as named-entity extraction from text. Algorithms include Hidden Markov Models, Maximum Entropy Markov Models, and Conditional Random Fields. These methods are implemented in an extensible system for finite state transducers.
#
# Topic models are useful for analyzing large collections of unlabeled text. The MALLET topic modeling toolkit contains efficient, sampling-based implementations of Latent Dirichlet Allocation, Pachinko Allocation, and Hierarchical LDA.
#
# Many of the algorithms in MALLET depend on numerical optimization. MALLET includes an efficient implementation of Limited Memory BFGS, among many other optimization methods.
#
# In addition to sophisticated Machine Learning applications, MALLET includes routines for transforming text documents into numerical representations that can then be processed efficiently. This process is implemented through a flexible system of "pipes", which handle distinct tasks such as tokenizing strings, removing stopwords, and converting sequences into count vectors.
#
# An add-on package to MALLET, called GRMM, contains support for inference in general graphical models, and training of CRFs with arbitrary graphical structure.
#
# ### Installation
#
# To build a Mallet 2.0 development release, you must have the Apache ant build tool installed. From the command prompt, first change to the mallet directory, and then type
# `ant`
#
# If `ant` finishes with `"BUILD SUCCESSFUL"`, Mallet is now ready to use.
#
# If you would like to deploy Mallet as part of a larger application, it is helpful to create a single ".jar" file that contains all of the compiled code. Once you have compiled the individual Mallet class files, use the command:
# `ant jar`
#
# This process will create a file "mallet.jar" in the "dist" directory within Mallet.
#
# ### Usage
#
# Once you have installed Mallet you can use it using the following command:
#
# ```bash
# bin/mallet [command] --option value --option value ...
# ```
# Type `bin/mallet` to get a list of commands, and use the option `--help` with any command to get a description of valid options.
#
# For details about the commands please visit the API documentation and website at: https://mimno.github.io/Mallet/
#
#
# ### List of Algorithms
#
# * Topic Modelling
#   * LDA
#   * Parallel LDA
#   * DMR LDA
#   * Hierarchical LDA
#   * Labeled LDA
#   * Polylingual Topic Model
#   * Hierarchical Pachinko Allocation Model (PAM)
#   * Weighted Topic Model
#   * LDA with integrated phrase discovery
#   * Word Embeddings (word2vec) using skip-gram with negative sampling
# * Classification
#   * AdaBoost
#   * Bagging
#   * Winnow
#   * C45 Decision Tree
#   * Ensemble Trainer
#   * Maximum Entropy Classifier (Multinomial Logistic Regression)
#   * Naive Bayes
#   * Rank Maximum Entropy Classifier
#   * Posterior Regularization Auxiliary Model
# * Clustering
#   * Greedy Agglomerative
#   * Hill Climbing
#   * K-Means
#   * K-Best
# * Sequence Prediction Models
#   * Conditional Random Fields
#   * Maximum Entropy Markov Models
#   * Hidden Markov Models
#   * Semi-Supervised Sequence Prediction Models
# * Linear Regression
