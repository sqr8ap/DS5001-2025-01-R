# %% [markdown]
# # M08a Homework
# - Name: Sam Remmey
# - Net ID: sqr8ap
# - URL of this file in GitHub:

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
import plotly_express as px

pd.set_option('display.max_colwidth', None)

import warnings
warnings.filterwarnings('ignore')

import configparser
config = configparser.ConfigParser()
config.read('../../../env.ini')
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']

# %%
data_prefix = 'novels'

OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']
PARA = OHCO[:3]
CHAP = OHCO[:2]
BOOK = OHCO[:1]

# %%
TOKENS = pd.read_csv(f'{data_home}/{data_prefix}-CORPUS.csv').set_index(OHCO)
TOKENS.sample(3)
# Out:
#                                                      pos  term_str
# book_id         chap_id para_num sent_num token_num
# moonstone       68      6        5        11          IN        in
# styles          9       52       0        2          NNP  lawrence
# christmascarole 5       47       0        39          CC       and

# %%
LIB = pd.read_csv(f'{data_home}/{data_prefix}-LIB.csv').set_index('book_id')
LIB.sample(3)
# Out:
#                 genre_id author_id
# book_id
# usher                  g       poe
# christmascarole        g   dickens
# reddeath               g       poe

# %%
# CountVectorizer parameters
max_features = 4000
stop_words = 'english'

# LatentDirichletAllocation parameters
n_components = 20
max_iter = 5
learning_offset = 50.
random_state = 0

# Hyperparameters
n_words = 7

# %% [markdown]
# ### Topic model 1: paragraph as bag

# %%
BAG = PARA
BAG
# Out:
# ['book_id', 'chap_id', 'para_num']

# %%
DOCS_para = TOKENS[TOKENS.pos.str.match(r'^NNS?$')]\
    .groupby(BAG).term_str\
    .apply(lambda x: ' '.join(map(str,x)))\
    .to_frame()\
    .rename(columns={'term_str':'doc_str'})
DOCS_para.sample(3)
# Out:
#                                                                                                                                                                         doc_str
# book_id         chap_id para_num
# secretadversary 17      99        door opened faint light outside gas it first followed threshold picture force head crash glass minute door key lock door inside volley curses
# monk            2       84                                                                                                         eer lines world days remorse conscience here
# secretadversary 24      47                                                                                                                                                 head

# %%
count_engine = CountVectorizer(max_features=max_features, stop_words='english')
count_model = count_engine.fit_transform(DOCS_para.doc_str)
TERMS_para = count_engine.get_feature_names_out()

VOCAB_para = pd.DataFrame(index=TERMS_para)
VOCAB_para.index.name = 'term_str'

DTM_para = pd.DataFrame(count_model.toarray(), index=DOCS_para.index, columns=TERMS_para)

# %%
VOCAB_para['doc_count'] = DTM_para.astype('bool').astype('int').sum()
DOCS_para['term_count'] = DTM_para.sum(1)

# %%
VOCAB_para.sample(3)
# Out:
#            doc_count
# term_str
# police           182
# range             14
# endeavour         17

# %%
lda_engine = LDA(n_components=n_components, max_iter=max_iter, learning_offset=learning_offset, random_state=random_state)

# %%
TNAMES_para = [f"T{str(x).zfill(len(str(n_components)))}" for x in range(n_components)]

# %%
## Theta

lda_model = lda_engine.fit_transform(count_model)

THETA_para = pd.DataFrame(lda_model, index=DOCS_para.index)
THETA_para.columns.name = 'topic_id'
THETA_para.columns = TNAMES_para

# %%
THETA_para.sample(10).T.style.background_gradient(cmap="YlGnBu", axis=None)
# Out:
# <style type="text/css">
# #T_2625f_row0_col0, #T_2625f_row1_col0, #T_2625f_row2_col0, #T_2625f_row3_col0, #T_2625f_row4_col0, #T_2625f_row5_col0, #T_2625f_row6_col0, #T_2625f_row7_col0, #T_2625f_row8_col0, #T_2625f_row9_col0, #T_2625f_row10_col0, #T_2625f_row11_col0, #T_2625f_row12_col0, #T_2625f_row13_col0, #T_2625f_row14_col0, #T_2625f_row15_col0, #T_2625f_row17_col0, #T_2625f_row18_col0, #T_2625f_row19_col0 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_2625f_row0_col1, #T_2625f_row0_col9, #T_2625f_row1_col1, #T_2625f_row1_col4, #T_2625f_row1_col9, #T_2625f_row2_col1, #T_2625f_row2_col4, #T_2625f_row2_col8, #T_2625f_row2_col9, #T_2625f_row3_col1, #T_2625f_row3_col4, #T_2625f_row3_col8, #T_2625f_row3_col9, #T_2625f_row4_col1, #T_2625f_row4_col4, #T_2625f_row4_col8, #T_2625f_row4_col9, #T_2625f_row5_col1, #T_2625f_row5_col8, #T_2625f_row6_col1, #T_2625f_row6_col4, #T_2625f_row6_col8, #T_2625f_row6_col9, #T_2625f_row7_col1, #T_2625f_row7_col4, #T_2625f_row7_col8, #T_2625f_row7_col9, #T_2625f_row8_col1, #T_2625f_row8_col4, #T_2625f_row8_col8, #T_2625f_row8_col9, #T_2625f_row9_col1, #T_2625f_row9_col4, #T_2625f_row9_col8, #T_2625f_row9_col9, #T_2625f_row10_col1, #T_2625f_row10_col4, #T_2625f_row10_col8, #T_2625f_row10_col9, #T_2625f_row11_col1, #T_2625f_row11_col4, #T_2625f_row11_col9, #T_2625f_row12_col1, #T_2625f_row12_col4, #T_2625f_row12_col8, #T_2625f_row12_col9, #T_2625f_row13_col1, #T_2625f_row13_col4, #T_2625f_row13_col8, #T_2625f_row13_col9, #T_2625f_row14_col8, #T_2625f_row15_col1, #T_2625f_row15_col8, #T_2625f_row15_col9, #T_2625f_row16_col1, #T_2625f_row16_col8, #T_2625f_row17_col8, #T_2625f_row17_col9, #T_2625f_row18_col1, #T_2625f_row18_col4, #T_2625f_row18_col8, #T_2625f_row18_col9, #T_2625f_row19_col4, #T_2625f_row19_col8, #T_2625f_row19_col9 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_2625f_row0_col2, #T_2625f_row1_col2, #T_2625f_row1_col6, #T_2625f_row2_col2, #T_2625f_row2_col6, #T_2625f_row3_col2, #T_2625f_row3_col6, #T_2625f_row4_col2, #T_2625f_row4_col6, #T_2625f_row5_col2, #T_2625f_row5_col6, #T_2625f_row6_col2, #T_2625f_row6_col6, #T_2625f_row7_col2, #T_2625f_row7_col6, #T_2625f_row8_col6, #T_2625f_row9_col2, #T_2625f_row9_col6, #T_2625f_row10_col2, #T_2625f_row10_col6, #T_2625f_row11_col2, #T_2625f_row12_col2, #T_2625f_row12_col6, #T_2625f_row13_col2, #T_2625f_row13_col6, #T_2625f_row14_col2, #T_2625f_row14_col6, #T_2625f_row15_col2, #T_2625f_row15_col6, #T_2625f_row16_col2, #T_2625f_row17_col2, #T_2625f_row17_col6, #T_2625f_row18_col2, #T_2625f_row18_col6, #T_2625f_row19_col2, #T_2625f_row19_col6 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_2625f_row0_col3, #T_2625f_row1_col3, #T_2625f_row2_col3, #T_2625f_row3_col3, #T_2625f_row4_col3, #T_2625f_row5_col3, #T_2625f_row7_col3, #T_2625f_row8_col3, #T_2625f_row9_col3, #T_2625f_row11_col3, #T_2625f_row12_col3, #T_2625f_row13_col3, #T_2625f_row14_col3, #T_2625f_row15_col3, #T_2625f_row16_col3, #T_2625f_row17_col3, #T_2625f_row18_col3, #T_2625f_row19_col3 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_2625f_row0_col4 {
#   background-color: #dcf1b2;
#   color: #000000;
# }
# #T_2625f_row0_col5, #T_2625f_row2_col5, #T_2625f_row3_col5, #T_2625f_row4_col5, #T_2625f_row6_col5, #T_2625f_row7_col5, #T_2625f_row8_col5, #T_2625f_row9_col5, #T_2625f_row10_col5, #T_2625f_row11_col5, #T_2625f_row12_col5, #T_2625f_row13_col5, #T_2625f_row14_col5, #T_2625f_row15_col5, #T_2625f_row16_col5, #T_2625f_row17_col5, #T_2625f_row18_col5, #T_2625f_row19_col5 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_2625f_row0_col6 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_2625f_row0_col7, #T_2625f_row1_col7, #T_2625f_row2_col7, #T_2625f_row3_col7, #T_2625f_row5_col7, #T_2625f_row6_col7, #T_2625f_row7_col7, #T_2625f_row8_col7, #T_2625f_row9_col7, #T_2625f_row10_col7, #T_2625f_row11_col7, #T_2625f_row12_col7, #T_2625f_row13_col7, #T_2625f_row14_col7, #T_2625f_row15_col7, #T_2625f_row16_col7, #T_2625f_row17_col7, #T_2625f_row18_col7 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_2625f_row0_col8 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_2625f_row1_col5 {
#   background-color: #61c2bf;
#   color: #000000;
# }
# #T_2625f_row1_col8 {
#   background-color: #92d5b9;
#   color: #000000;
# }
# #T_2625f_row4_col7 {
#   background-color: #253795;
#   color: #f1f1f1;
# }
# #T_2625f_row5_col4 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_2625f_row5_col5 {
#   background-color: #206eb0;
#   color: #f1f1f1;
# }
# #T_2625f_row5_col9 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_2625f_row6_col3, #T_2625f_row10_col3 {
#   background-color: #59bfc0;
#   color: #000000;
# }
# #T_2625f_row8_col2 {
#   background-color: #0b1f5e;
#   color: #f1f1f1;
# }
# #T_2625f_row11_col6 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_2625f_row11_col8 {
#   background-color: #85cfba;
#   color: #000000;
# }
# #T_2625f_row14_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_2625f_row14_col4 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_2625f_row14_col9 {
#   background-color: #42b6c4;
#   color: #f1f1f1;
# }
# #T_2625f_row15_col4 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_2625f_row16_col0 {
#   background-color: #1f7bb6;
#   color: #f1f1f1;
# }
# #T_2625f_row16_col4 {
#   background-color: #d7efb3;
#   color: #000000;
# }
# #T_2625f_row16_col6 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_2625f_row16_col9 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_2625f_row17_col1 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_2625f_row17_col4 {
#   background-color: #e3f4b2;
#   color: #000000;
# }
# #T_2625f_row19_col1 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_2625f_row19_col7 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# </style>
# <table id="T_2625f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >book_id</th>
#       <th id="T_2625f_level0_col0" class="col_heading level0 col0" colspan="2">udolpho</th>
#       <th id="T_2625f_level0_col2" class="col_heading level0 col2" >moonstone</th>
#       <th id="T_2625f_level0_col3" class="col_heading level0 col3" >dracula</th>
#       <th id="T_2625f_level0_col4" class="col_heading level0 col4" colspan="2">udolpho</th>
#       <th id="T_2625f_level0_col6" class="col_heading level0 col6" colspan="2">secretadversary</th>
#       <th id="T_2625f_level0_col8" class="col_heading level0 col8" >scarlet</th>
#       <th id="T_2625f_level0_col9" class="col_heading level0 col9" >monk</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >chap_id</th>
#       <th id="T_2625f_level1_col0" class="col_heading level1 col0" >18</th>
#       <th id="T_2625f_level1_col1" class="col_heading level1 col1" >25</th>
#       <th id="T_2625f_level1_col2" class="col_heading level1 col2" >77</th>
#       <th id="T_2625f_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_2625f_level1_col4" class="col_heading level1 col4" >34</th>
#       <th id="T_2625f_level1_col5" class="col_heading level1 col5" >20</th>
#       <th id="T_2625f_level1_col6" class="col_heading level1 col6" >21</th>
#       <th id="T_2625f_level1_col7" class="col_heading level1 col7" >19</th>
#       <th id="T_2625f_level1_col8" class="col_heading level1 col8" >7</th>
#       <th id="T_2625f_level1_col9" class="col_heading level1 col9" >7</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >para_num</th>
#       <th id="T_2625f_level2_col0" class="col_heading level2 col0" >70</th>
#       <th id="T_2625f_level2_col1" class="col_heading level2 col1" >46</th>
#       <th id="T_2625f_level2_col2" class="col_heading level2 col2" >22</th>
#       <th id="T_2625f_level2_col3" class="col_heading level2 col3" >1</th>
#       <th id="T_2625f_level2_col4" class="col_heading level2 col4" >18</th>
#       <th id="T_2625f_level2_col5" class="col_heading level2 col5" >104</th>
#       <th id="T_2625f_level2_col6" class="col_heading level2 col6" >52</th>
#       <th id="T_2625f_level2_col7" class="col_heading level2 col7" >62</th>
#       <th id="T_2625f_level2_col8" class="col_heading level2 col8" >43</th>
#       <th id="T_2625f_level2_col9" class

# %%
## Phi

PHI_para = pd.DataFrame(lda_engine.components_, columns=TERMS_para, index=TNAMES_para)
PHI_para.index.name = 'topic_id'
PHI_para.columns.name = 'term_str'

# %%
PHI_para.T.sample(10).style.background_gradient(cmap="YlGnBu", axis=None)
# Out:
# <style type="text/css">
# #T_8fe73_row0_col0 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_8fe73_row0_col1 {
#   background-color: #46b8c3;
#   color: #f1f1f1;
# }
# #T_8fe73_row0_col2, #T_8fe73_row2_col18, #T_8fe73_row7_col1 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_8fe73_row0_col3 {
#   background-color: #cdebb4;
#   color: #000000;
# }
# #T_8fe73_row0_col4, #T_8fe73_row1_col0, #T_8fe73_row1_col1, #T_8fe73_row1_col2, #T_8fe73_row1_col4, #T_8fe73_row1_col5, #T_8fe73_row1_col7, #T_8fe73_row1_col8, #T_8fe73_row1_col9, #T_8fe73_row1_col10, #T_8fe73_row1_col11, #T_8fe73_row1_col12, #T_8fe73_row1_col13, #T_8fe73_row1_col15, #T_8fe73_row1_col16, #T_8fe73_row1_col17, #T_8fe73_row1_col19, #T_8fe73_row2_col0, #T_8fe73_row2_col1, #T_8fe73_row2_col2, #T_8fe73_row2_col4, #T_8fe73_row2_col5, #T_8fe73_row2_col7, #T_8fe73_row2_col10, #T_8fe73_row2_col11, #T_8fe73_row2_col13, #T_8fe73_row2_col14, #T_8fe73_row2_col15, #T_8fe73_row2_col16, #T_8fe73_row2_col17, #T_8fe73_row2_col19, #T_8fe73_row3_col13, #T_8fe73_row3_col16, #T_8fe73_row4_col0, #T_8fe73_row4_col1, #T_8fe73_row4_col2, #T_8fe73_row4_col4, #T_8fe73_row4_col6, #T_8fe73_row4_col9, #T_8fe73_row4_col11, #T_8fe73_row4_col18, #T_8fe73_row4_col19, #T_8fe73_row5_col0, #T_8fe73_row5_col3, #T_8fe73_row5_col4, #T_8fe73_row5_col5, #T_8fe73_row5_col7, #T_8fe73_row5_col8, #T_8fe73_row5_col10, #T_8fe73_row5_col11, #T_8fe73_row5_col12, #T_8fe73_row5_col14, #T_8fe73_row5_col15, #T_8fe73_row5_col18, #T_8fe73_row5_col19, #T_8fe73_row6_col0, #T_8fe73_row6_col1, #T_8fe73_row6_col2, #T_8fe73_row6_col3, #T_8fe73_row6_col4, #T_8fe73_row6_col6, #T_8fe73_row6_col8, #T_8fe73_row6_col9, #T_8fe73_row6_col10, #T_8fe73_row6_col11, #T_8fe73_row6_col12, #T_8fe73_row6_col13, #T_8fe73_row6_col15, #T_8fe73_row6_col16, #T_8fe73_row6_col17, #T_8fe73_row6_col18, #T_8fe73_row7_col0, #T_8fe73_row7_col2, #T_8fe73_row7_col3, #T_8fe73_row7_col5, #T_8fe73_row7_col6, #T_8fe73_row7_col7, #T_8fe73_row7_col8, #T_8fe73_row7_col9, #T_8fe73_row7_col10, #T_8fe73_row7_col12, #T_8fe73_row7_col14, #T_8fe73_row7_col15, #T_8fe73_row7_col17, #T_8fe73_row7_col18, #T_8fe73_row8_col0, #T_8fe73_row8_col2, #T_8fe73_row8_col3, #T_8fe73_row8_col4, #T_8fe73_row8_col5, #T_8fe73_row8_col7, #T_8fe73_row8_col8, #T_8fe73_row8_col9, #T_8fe73_row8_col10, #T_8fe73_row8_col11, #T_8fe73_row8_col12, #T_8fe73_row8_col13, #T_8fe73_row8_col14, #T_8fe73_row8_col15, #T_8fe73_row8_col16, #T_8fe73_row8_col18, #T_8fe73_row8_col19, #T_8fe73_row9_col0, #T_8fe73_row9_col4, #T_8fe73_row9_col5, #T_8fe73_row9_col6, #T_8fe73_row9_col7, #T_8fe73_row9_col8, #T_8fe73_row9_col11, #T_8fe73_row9_col13, #T_8fe73_row9_col15, #T_8fe73_row9_col16, #T_8fe73_row9_col17 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_8fe73_row0_col5 {
#   background-color: #5fc1c0;
#   color: #000000;
# }
# #T_8fe73_row0_col6, #T_8fe73_row0_col8, #T_8fe73_row1_col3, #T_8fe73_row5_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_8fe73_row0_col7 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_8fe73_row0_col9, #T_8fe73_row3_col6, #T_8fe73_row3_col11, #T_8fe73_row3_col18, #T_8fe73_row5_col6 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_8fe73_row0_col10, #T_8fe73_row4_col14 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_8fe73_row0_col11, #T_8fe73_row3_col7, #T_8fe73_row3_col17, #T_8fe73_row4_col13, #T_8fe73_row6_col14, #T_8fe73_row6_col19, #T_8fe73_row8_col6, #T_8fe73_row9_col3 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_8fe73_row0_col12, #T_8fe73_row0_col14, #T_8fe73_row4_col15 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_8fe73_row0_col13, #T_8fe73_row4_col10, #T_8fe73_row7_col16 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_8fe73_row0_col15 {
#   background-color: #6fc7bd;
#   color: #000000;
# }
# #T_8fe73_row0_col16 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_8fe73_row0_col17 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_8fe73_row0_col18, #T_8fe73_row8_col17 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_8fe73_row0_col19 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_8fe73_row1_col6, #T_8fe73_row2_col8, #T_8fe73_row3_col4, #T_8fe73_row6_col5 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_8fe73_row1_col14, #T_8fe73_row3_col2, #T_8fe73_row3_col9, #T_8fe73_row4_col7, #T_8fe73_row5_col9, #T_8fe73_row9_col2, #T_8fe73_row9_col12 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_8fe73_row1_col18, #T_8fe73_row3_col3, #T_8fe73_row4_col3, #T_8fe73_row4_col8, #T_8fe73_row5_col2 {
#   background-color: #fdfed5;
#   color: #000000;
# }
# #T_8fe73_row2_col3 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_8fe73_row2_col6, #T_8fe73_row3_col14, #T_8fe73_row3_col19, #T_8fe73_row4_col12, #T_8fe73_row6_col7, #T_8fe73_row7_col13, #T_8fe73_row8_col1, #T_8fe73_row9_col10, #T_8fe73_row9_col19 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_8fe73_row2_col9 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_8fe73_row2_col12 {
#   background-color: #99d7b8;
#   color: #000000;
# }
# #T_8fe73_row3_col0 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_8fe73_row3_col1 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_8fe73_row3_col5 {
#   background-color: #97d6b9;
#   color: #000000;
# }
# #T_8fe73_row3_col8 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_8fe73_row3_col10, #T_8fe73_row3_col12, #T_8fe73_row5_col13, #T_8fe73_row5_col17, #T_8fe73_row9_col9 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_8fe73_row3_col15 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_8fe73_row4_col5 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_8fe73_row4_col16, #T_8fe73_row4_col17, #T_8fe73_row7_col4 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_8fe73_row5_col16, #T_8fe73_row9_col1 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_8fe73_row7_col11 {
#   background-color: #e0f3b2;
#   color: #000000;
# }
# #T_8fe73_row7_col19 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_8fe73_row9_col14 {
#   background-color: #daf0b3;
#   color: #000000;
# }
# #T_8fe73_row9_col18 {
#   background-color: #5bc0c0;
#   color: #000000;
# }
# </style>
# <table id="T_8fe73">
#   <thead>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th id="T_8fe73_level0_col0" class="col_heading level0 col0" >T00</th>
#       <th id="T_8fe73_level0_col1" class="col_heading level0 col1" >T01</th>
#       <th id="T_8fe73_level0_col2" class="col_heading level0 col2" >T02</th>
#       <th id="T_8fe73_level0_col3" class="col_heading level0 col3" >T03</th>
#       <th id="T_8fe73_level0_col4" class="col_heading level0 col4" >T04</th>
#       <th id="T_8fe73_level0_col5" class="col_heading level0 col5" >T05</th>
#       <th id="T_8fe73_level0_col6" class="col_heading level0 col6" >T06</th>
#       <th id="T_8fe73_level0_col7" class="col_heading level0 col7" >T07</th>
#       <th id="T_8fe73_level0_col8" class="col_heading level0 col8" >T08</th>
#       <th id="T_8fe73_level0_col9" class="col_heading level0 col9" >T09</th>
#       <th id="T_8fe73_level0_col10" class="col_heading level0 col10" >T10</th>
#       <th id="T_8fe73_level0_col11" class="col_heading level0 col11" >T11</th>
#       <th id="T_8fe73_level0_col12" class="col_heading level0 col12" >T12</th>
#       <th id="T_8fe73_level0_col13" class="col_heading level0 col13" >T13</th>
#       <th id="T_8fe73_level0_col14" class="col_heading level0 col14" >T14</th>
#       <th id="T_8fe73_level0_col15" class="col_heading level0 col15" >T15</th>
#       <th id="T_8fe73_level0_col16" class="col_heading level0 col16" >T16</th>
#       <th id="T_8fe73_level0_col17" class="col_heading level0 col17" >T17</th>
#       <th id="T_8fe73_level0_col18" class="col_heading level0 col18" >T18</th>
#       <th id="T_8fe73_level0_col19" class="col_heading level0 col19" >T19</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;

# %%
## Topics

TOPICS_para = PHI_para.stack().groupby('topic_id')\
    .apply(lambda x: ' '.join(x.sort_values(ascending=False).head(n_words).reset_index().term_str))\
    .to_frame('top_terms')

# %%
TOPICS_para.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_36690">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36690_level0_col0" class="col_heading level0 col0" >top_terms</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36690_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_36690_row0_col0" class="data row0 col0" >time mother house girl lady family matter</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row1" class="row_heading level0 row1" >T01</th>
#       <td id="T_36690_row1_col0" class="data row1 col0" >man lady wife sort room help way</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row2" class="row_heading level0 row2" >T02</th>
#       <td id="T_36690_row2_col0" class="data row2 col0" >words ah things time hand note sure</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row3" class="row_heading level0 row3" >T03</th>
#       <td id="T_36690_row3_col0" class="data row3 col0" >house door night friend body servants gentleman</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row4" class="row_heading level0 row4" >T04</th>
#       <td id="T_36690_row4_col0" class="data row4 col0" >opinion power man affair eyes manner way</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row5" class="row_heading level0 row5" >T05</th>
#       <td id="T_36690_row5_col0" class="data row5 col0" >heart moment eyes life countenance tears world</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row6" class="row_heading level0 row6" >T06</th>
#       <td id="T_36690_row6_col0" class="data row6 col0" >night dont business mind work time dinner</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row7" class="row_heading level0 row7" >T07</th>
#       <td id="T_36690_row7_col0" class="data row7 col0" >day letter time dear friends friend way</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row8" class="row_heading level0 row8" >T08</th>
#       <td id="T_36690_row8_col0" class="data row8 col0" >morning house time place way thing mr</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row9" class="row_heading level0 row9" >T09</th>
#       <td id="T_36690_row9_col0" class="data row9 col0" >oh man good head end castle moment</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row10" class="row_heading level0 row10" >T10</th>
#       <td id="T_36690_row10_col0" class="data row10 col0" >room bed case table chair door window</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row11" class="row_heading level0 row11" >T11</th>
#       <td id="T_36690_row11_col0" class="data row11 col0" >yes father son box matter place way</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row12" class="row_heading level0 row12" >T12</th>
#       <td id="T_36690_row12_col0" class="data row12 col0" >room house window day windows time morning</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row13" class="row_heading level0 row13" >T13</th>
#       <td id="T_36690_row13_col0" class="data row13 col0" >work right word way time thou tm</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row14" class="row_heading level0 row14" >T14</th>
#       <td id="T_36690_row14_col0" class="data row14 col0" >sir voice light sound steps door distance</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row15" class="row_heading level0 row15" >T15</th>
#       <td id="T_36690_row15_col0" class="data row15 col0" >face eyes hand hands night man lips</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row16" class="row_heading level0 row16" >T16</th>
#       <td id="T_36690_row16_col0" class="data row16 col0" >door room chamber hand apartment look moment</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row17" class="row_heading level0 row17" >T17</th>
#       <td id="T_36690_row17_col0" class="data row17 col0" >heart man mind love time evening friend</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row18" class="row_heading level0 row18" >T18</th>
#       <td id="T_36690_row18_col0" class="data row18 col0" >day country sun home sea mountains place</td>
#     </tr>
#     <tr>
#       <th id="T_36690_level0_row19" class="row_heading level0 row19" >T19</th>
#       <td id="T_36690_row19_col0" class="data row19 col0" >subject person tuppence chateau lord night course</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Topic model 2: chapter as bag

# %%
BAG = CHAP
BAG
# Out:
# ['book_id', 'chap_id']

# %%
DOCS_chap = TOKENS[TOKENS.pos.str.match(r'^NNS?$')]\
    .groupby(BAG).term_str\
    .apply(lambda x: ' '.join(map(str,x)))\
    .to_frame()\
    .rename(columns={'term_str':'doc_str'})

# %%
count_engine = CountVectorizer(max_features=max_features, stop_words='english')
count_model = count_engine.fit_transform(DOCS_chap.doc_str)
TERMS_chap = count_engine.get_feature_names_out()

VOCAB_chap = pd.DataFrame(index=TERMS_chap)
VOCAB_chap.index.name = 'term_str'

DTM_chap = pd.DataFrame(count_model.toarray(), index=DOCS_chap.index, columns=TERMS_chap)

# %%
VOCAB_chap['doc_count'] = DTM_chap.astype('bool').astype('int').sum()
DOCS_chap['term_count'] = DTM_chap.sum(1)

# %%
VOCAB_chap.sample(3)
# Out:
#           doc_count
# term_str
# environs         13
# safe             18
# peril            13

# %%
lda_engine = LDA(n_components=n_components, max_iter=max_iter, learning_offset=learning_offset, random_state=random_state)

# %%
TNAMES_chap = [f"T{str(x).zfill(len(str(n_components)))}" for x in range(n_components)]

# %%
## Theta

lda_model = lda_engine.fit_transform(count_model)

THETA_chap = pd.DataFrame(lda_model, index=DOCS_chap.index)
THETA_chap.columns.name = 'topic_id'
THETA_chap.columns = TNAMES_chap

# %%
THETA_chap.sample(10).T.style.background_gradient(cmap="YlGnBu", axis=None)
# Out:
# <style type="text/css">
# #T_6fb89_row0_col0, #T_6fb89_row0_col1, #T_6fb89_row0_col2, #T_6fb89_row0_col3, #T_6fb89_row0_col4, #T_6fb89_row0_col5, #T_6fb89_row0_col6, #T_6fb89_row0_col7, #T_6fb89_row0_col8, #T_6fb89_row1_col0, #T_6fb89_row1_col1, #T_6fb89_row1_col3, #T_6fb89_row1_col4, #T_6fb89_row1_col5, #T_6fb89_row1_col6, #T_6fb89_row1_col8, #T_6fb89_row2_col0, #T_6fb89_row2_col1, #T_6fb89_row2_col2, #T_6fb89_row2_col3, #T_6fb89_row2_col4, #T_6fb89_row2_col5, #T_6fb89_row2_col6, #T_6fb89_row2_col7, #T_6fb89_row2_col8, #T_6fb89_row2_col9, #T_6fb89_row3_col0, #T_6fb89_row3_col2, #T_6fb89_row3_col3, #T_6fb89_row3_col4, #T_6fb89_row3_col5, #T_6fb89_row3_col6, #T_6fb89_row3_col8, #T_6fb89_row3_col9, #T_6fb89_row4_col0, #T_6fb89_row4_col1, #T_6fb89_row4_col2, #T_6fb89_row4_col3, #T_6fb89_row4_col4, #T_6fb89_row4_col5, #T_6fb89_row4_col6, #T_6fb89_row4_col7, #T_6fb89_row4_col8, #T_6fb89_row4_col9, #T_6fb89_row5_col1, #T_6fb89_row5_col2, #T_6fb89_row5_col6, #T_6fb89_row5_col7, #T_6fb89_row5_col8, #T_6fb89_row5_col9, #T_6fb89_row6_col0, #T_6fb89_row6_col1, #T_6fb89_row6_col2, #T_6fb89_row6_col3, #T_6fb89_row6_col4, #T_6fb89_row6_col5, #T_6fb89_row6_col6, #T_6fb89_row6_col7, #T_6fb89_row6_col8, #T_6fb89_row7_col5, #T_6fb89_row7_col7, #T_6fb89_row8_col0, #T_6fb89_row8_col1, #T_6fb89_row8_col2, #T_6fb89_row8_col3, #T_6fb89_row8_col4, #T_6fb89_row8_col5, #T_6fb89_row8_col6, #T_6fb89_row8_col7, #T_6fb89_row8_col8, #T_6fb89_row8_col9, #T_6fb89_row9_col0, #T_6fb89_row9_col1, #T_6fb89_row9_col2, #T_6fb89_row9_col3, #T_6fb89_row9_col4, #T_6fb89_row9_col5, #T_6fb89_row9_col6, #T_6fb89_row9_col7, #T_6fb89_row9_col8, #T_6fb89_row9_col9, #T_6fb89_row10_col0, #T_6fb89_row10_col1, #T_6fb89_row10_col2, #T_6fb89_row10_col3, #T_6fb89_row10_col4, #T_6fb89_row10_col5, #T_6fb89_row10_col6, #T_6fb89_row10_col7, #T_6fb89_row10_col8, #T_6fb89_row10_col9, #T_6fb89_row11_col0, #T_6fb89_row11_col1, #T_6fb89_row11_col2, #T_6fb89_row11_col3, #T_6fb89_row11_col4, #T_6fb89_row11_col6, #T_6fb89_row11_col7, #T_6fb89_row11_col8, #T_6fb89_row11_col9, #T_6fb89_row12_col0, #T_6fb89_row12_col1, #T_6fb89_row12_col2, #T_6fb89_row12_col3, #T_6fb89_row12_col4, #T_6fb89_row12_col5, #T_6fb89_row12_col6, #T_6fb89_row12_col7, #T_6fb89_row12_col8, #T_6fb89_row12_col9, #T_6fb89_row13_col0, #T_6fb89_row13_col1, #T_6fb89_row13_col2, #T_6fb89_row13_col3, #T_6fb89_row13_col4, #T_6fb89_row13_col5, #T_6fb89_row13_col6, #T_6fb89_row13_col7, #T_6fb89_row13_col8, #T_6fb89_row13_col9, #T_6fb89_row14_col0, #T_6fb89_row14_col1, #T_6fb89_row14_col2, #T_6fb89_row14_col3, #T_6fb89_row14_col4, #T_6fb89_row14_col5, #T_6fb89_row14_col6, #T_6fb89_row14_col7, #T_6fb89_row14_col8, #T_6fb89_row15_col0, #T_6fb89_row15_col1, #T_6fb89_row15_col2, #T_6fb89_row15_col3, #T_6fb89_row15_col4, #T_6fb89_row15_col5, #T_6fb89_row15_col6, #T_6fb89_row15_col7, #T_6fb89_row15_col8, #T_6fb89_row15_col9, #T_6fb89_row16_col1, #T_6fb89_row16_col2, #T_6fb89_row16_col3, #T_6fb89_row16_col4, #T_6fb89_row16_col5, #T_6fb89_row16_col6, #T_6fb89_row16_col7, #T_6fb89_row16_col9, #T_6fb89_row17_col0, #T_6fb89_row17_col1, #T_6fb89_row17_col2, #T_6fb89_row17_col3, #T_6fb89_row17_col4, #T_6fb89_row17_col5, #T_6fb89_row17_col6, #T_6fb89_row17_col7, #T_6fb89_row17_col8, #T_6fb89_row17_col9, #T_6fb89_row18_col0, #T_6fb89_row18_col1, #T_6fb89_row18_col5, #T_6fb89_row18_col7, #T_6fb89_row18_col9, #T_6fb89_row19_col1, #T_6fb89_row19_col2, #T_6fb89_row19_col3, #T_6fb89_row19_col6, #T_6fb89_row19_col9 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_6fb89_row0_col9 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_6fb89_row1_col2 {
#   background-color: #243d98;
#   color: #f1f1f1;
# }
# #T_6fb89_row1_col7 {
#   background-color: #152772;
#   color: #f1f1f1;
# }
# #T_6fb89_row1_col9 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_6fb89_row3_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_6fb89_row3_col7 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_6fb89_row5_col0 {
#   background-color: #75c9bd;
#   color: #000000;
# }
# #T_6fb89_row5_col3 {
#   background-color: #a7dcb7;
#   color: #000000;
# }
# #T_6fb89_row5_col4 {
#   background-color: #9ed9b8;
#   color: #000000;
# }
# #T_6fb89_row5_col5 {
#   background-color: #1e83ba;
#   color: #f1f1f1;
# }
# #T_6fb89_row6_col9 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_6fb89_row7_col0 {
#   background-color: #2fa4c2;
#   color: #f1f1f1;
# }
# #T_6fb89_row7_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_6fb89_row7_col2 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_6fb89_row7_col3 {
#   background-color: #4ab9c3;
#   color: #f1f1f1;
# }
# #T_6fb89_row7_col4 {
#   background-color: #c8e9b4;
#   color: #000000;
# }
# #T_6fb89_row7_col6 {
#   background-color: #39adc3;
#   color: #f1f1f1;
# }
# #T_6fb89_row7_col8 {
#   background-color: #1f82b9;
#   color: #f1f1f1;
# }
# #T_6fb89_row7_col9 {
#   background-color: #1e8abd;
#   color: #f1f1f1;
# }
# #T_6fb89_row11_col5, #T_6fb89_row16_col0, #T_6fb89_row16_col8 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_6fb89_row14_col9 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_6fb89_row18_col2 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_6fb89_row18_col3 {
#   background-color: #bde5b5;
#   color: #000000;
# }
# #T_6fb89_row18_col4 {
#   background-color: #76cabc;
#   color: #000000;
# }
# #T_6fb89_row18_col6 {
#   background-color: #3aaec3;
#   color: #f1f1f1;
# }
# #T_6fb89_row18_col8 {
#   background-color: #cbebb4;
#   color: #000000;
# }
# #T_6fb89_row19_col0 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_6fb89_row19_col4 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_6fb89_row19_col5 {
#   background-color: #78cbbc;
#   color: #000000;
# }
# #T_6fb89_row19_col7 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_6fb89_row19_col8 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# </style>
# <table id="T_6fb89">
#   <thead>
#     <tr>
#       <th class="index_name level0" >book_id</th>
#       <th id="T_6fb89_level0_col0" class="col_heading level0 col0" >northangerabbey</th>
#       <th id="T_6fb89_level0_col1" class="col_heading level0 col1" >moonstone</th>
#       <th id="T_6fb89_level0_col2" class="col_heading level0 col2" >secretadversary</th>
#       <th id="T_6fb89_level0_col3" class="col_heading level0 col3" >northangerabbey</th>
#       <th id="T_6fb89_level0_col4" class="col_heading level0 col4" >frankenstein</th>
#       <th id="T_6fb89_level0_col5" class="col_heading level0 col5" >udolpho</th>
#       <th id="T_6fb89_level0_col6" class="col_heading level0 col6" >northangerabbey</th>
#       <th id="T_6fb89_level0_col7" class="col_heading level0 col7" >styles</th>
#       <th id="T_6fb89_level0_col8" class="col_heading level0 col8" >northangerabbey</th>
#       <th id="T_6fb89_level0_col9" class="col_heading level0 col9" >moonstone</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >chap_id</th>
#       <th id="T_6fb89_level1_col0" class="col_heading level1 col0" >28</th>
#       <th id="T_6fb89_level1_col1" class="col_heading level1 col1" >71</th>
#       <th id="T_6fb89_level1_col2" class="col_heading level1 col2" >14</th>
#       <th id="T_6fb89_level1_col3" class="col_heading level1 col3" >4</th>
#       <th id="T_6fb89_level1_col4" class="col_heading level1 col4" >38</th>
#       <th id="T_6fb89_level1_col5" class="col_heading level1 col5" >54</th>
#       <th id="T_6fb89_level1_col6" class="col_heading level1 col6" >27</th>
#       <th id="T_6fb89_level1_col7" class="col_heading level1 col7" >9</th>
#       <th id="T_6fb89_level1_col8" class="col_heading level1 col8" >26</th>
#       <th id="T_6fb89_level1_col9" class="col_heading level1 col9" >78</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fb89_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_6fb89_row0_col0" class="data row0 col0" >0.000097</td>
#       <td id="T_6fb89_row0_col1" class="data row0 col1" >0.000088</td>
#       <td id="T_6fb89_row0_col2" class="data row0 col2" >0.000172</td>
#       <td id="T_6fb89_row0_col3" class="data row0 col3" >0.000258</td>
#       <td id="T_6fb89_row0_col4" class="data row0 col4" >0.000114</td>
#       <td id="T_6fb8

# %%
## Phi

PHI_chap = pd.DataFrame(lda_engine.components_, columns=TERMS_chap, index=TNAMES_chap)
PHI_chap.index.name = 'topic_id'
PHI_chap.columns.name = 'term_str'

# %%
PHI_chap.T.sample(10).style.background_gradient(cmap="YlGnBu", axis=None)
# Out:
# <style type="text/css">
# #T_046f0_row0_col0, #T_046f0_row1_col6, #T_046f0_row2_col14, #T_046f0_row6_col17, #T_046f0_row8_col2, #T_046f0_row9_col14 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_046f0_row0_col1 {
#   background-color: #269bc1;
#   color: #f1f1f1;
# }
# #T_046f0_row0_col2, #T_046f0_row0_col3, #T_046f0_row0_col4, #T_046f0_row0_col8, #T_046f0_row0_col9, #T_046f0_row0_col10, #T_046f0_row0_col11, #T_046f0_row0_col12, #T_046f0_row0_col13, #T_046f0_row0_col14, #T_046f0_row0_col15, #T_046f0_row0_col16, #T_046f0_row0_col17, #T_046f0_row0_col19, #T_046f0_row1_col0, #T_046f0_row1_col2, #T_046f0_row1_col3, #T_046f0_row1_col4, #T_046f0_row1_col7, #T_046f0_row1_col10, #T_046f0_row1_col11, #T_046f0_row1_col12, #T_046f0_row1_col13, #T_046f0_row1_col16, #T_046f0_row1_col19, #T_046f0_row2_col0, #T_046f0_row2_col1, #T_046f0_row2_col2, #T_046f0_row2_col3, #T_046f0_row2_col4, #T_046f0_row2_col5, #T_046f0_row2_col7, #T_046f0_row2_col8, #T_046f0_row2_col9, #T_046f0_row2_col10, #T_046f0_row2_col11, #T_046f0_row2_col12, #T_046f0_row2_col13, #T_046f0_row2_col16, #T_046f0_row2_col18, #T_046f0_row2_col19, #T_046f0_row3_col0, #T_046f0_row3_col1, #T_046f0_row3_col2, #T_046f0_row3_col3, #T_046f0_row3_col4, #T_046f0_row3_col6, #T_046f0_row3_col9, #T_046f0_row3_col11, #T_046f0_row3_col12, #T_046f0_row3_col13, #T_046f0_row3_col14, #T_046f0_row4_col0, #T_046f0_row4_col3, #T_046f0_row4_col4, #T_046f0_row4_col6, #T_046f0_row4_col7, #T_046f0_row4_col8, #T_046f0_row4_col9, #T_046f0_row4_col10, #T_046f0_row4_col11, #T_046f0_row4_col12, #T_046f0_row4_col13, #T_046f0_row4_col15, #T_046f0_row4_col16, #T_046f0_row4_col18, #T_046f0_row5_col0, #T_046f0_row5_col2, #T_046f0_row5_col3, #T_046f0_row5_col4, #T_046f0_row5_col6, #T_046f0_row5_col8, #T_046f0_row5_col10, #T_046f0_row5_col12, #T_046f0_row5_col13, #T_046f0_row5_col15, #T_046f0_row5_col16, #T_046f0_row5_col18, #T_046f0_row5_col19, #T_046f0_row6_col0, #T_046f0_row6_col2, #T_046f0_row6_col3, #T_046f0_row6_col4, #T_046f0_row6_col8, #T_046f0_row6_col10, #T_046f0_row6_col12, #T_046f0_row6_col14, #T_046f0_row7_col2, #T_046f0_row7_col4, #T_046f0_row7_col5, #T_046f0_row7_col6, #T_046f0_row7_col8, #T_046f0_row7_col9, #T_046f0_row7_col10, #T_046f0_row7_col11, #T_046f0_row7_col12, #T_046f0_row7_col13, #T_046f0_row7_col14, #T_046f0_row7_col16, #T_046f0_row7_col17, #T_046f0_row7_col19, #T_046f0_row8_col0, #T_046f0_row8_col6, #T_046f0_row8_col8, #T_046f0_row8_col11, #T_046f0_row8_col12, #T_046f0_row8_col13, #T_046f0_row8_col14, #T_046f0_row8_col15, #T_046f0_row8_col16, #T_046f0_row9_col0, #T_046f0_row9_col1, #T_046f0_row9_col2, #T_046f0_row9_col3, #T_046f0_row9_col4, #T_046f0_row9_col5, #T_046f0_row9_col6, #T_046f0_row9_col7, #T_046f0_row9_col10, #T_046f0_row9_col11, #T_046f0_row9_col12, #T_046f0_row9_col13, #T_046f0_row9_col15, #T_046f0_row9_col16, #T_046f0_row9_col17, #T_046f0_row9_col18, #T_046f0_row9_col19 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_046f0_row0_col5, #T_046f0_row6_col18 {
#   background-color: #feffd8;
#   color: #000000;
# }
# #T_046f0_row0_col6 {
#   background-color: #4cbac2;
#   color: #f1f1f1;
# }
# #T_046f0_row0_col7 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_046f0_row0_col18, #T_046f0_row1_col8, #T_046f0_row3_col15, #T_046f0_row5_col9, #T_046f0_row5_col17 {
#   background-color: #f9fdcb;
#   color: #000000;
# }
# #T_046f0_row1_col1 {
#   background-color: #67c4be;
#   color: #000000;
# }
# #T_046f0_row1_col5, #T_046f0_row5_col5, #T_046f0_row6_col9 {
#   background-color: #cfecb3;
#   color: #000000;
# }
# #T_046f0_row1_col9, #T_046f0_row6_col15 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# #T_046f0_row1_col14 {
#   background-color: #a9ddb7;
#   color: #000000;
# }
# #T_046f0_row1_col15, #T_046f0_row5_col14, #T_046f0_row6_col16 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_046f0_row1_col17 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_046f0_row1_col18, #T_046f0_row3_col8, #T_046f0_row3_col19 {
#   background-color: #f3fabf;
#   color: #000000;
# }
# #T_046f0_row2_col6 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_046f0_row2_col15 {
#   background-color: #f4fbc0;
#   color: #000000;
# }
# #T_046f0_row2_col17 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_046f0_row3_col5 {
#   background-color: #abdeb7;
#   color: #000000;
# }
# #T_046f0_row3_col7 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_046f0_row3_col10, #T_046f0_row4_col1 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_046f0_row3_col16, #T_046f0_row4_col2, #T_046f0_row8_col19, #T_046f0_row9_col9 {
#   background-color: #fafdce;
#   color: #000000;
# }
# #T_046f0_row3_col17 {
#   background-color: #d9f0b3;
#   color: #000000;
# }
# #T_046f0_row3_col18 {
#   background-color: #f6fbc5;
#   color: #000000;
# }
# #T_046f0_row4_col5, #T_046f0_row6_col6, #T_046f0_row7_col0 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_046f0_row4_col14 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_046f0_row4_col17 {
#   background-color: #f4fbc1;
#   color: #000000;
# }
# #T_046f0_row4_col19 {
#   background-color: #b0e0b6;
#   color: #000000;
# }
# #T_046f0_row5_col1 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_046f0_row5_col7 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_046f0_row5_col11 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_046f0_row6_col1 {
#   background-color: #3cb1c3;
#   color: #f1f1f1;
# }
# #T_046f0_row6_col5 {
#   background-color: #225da8;
#   color: #f1f1f1;
# }
# #T_046f0_row6_col7 {
#   background-color: #36abc3;
#   color: #f1f1f1;
# }
# #T_046f0_row6_col11 {
#   background-color: #89d1ba;
#   color: #000000;
# }
# #T_046f0_row6_col13 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_046f0_row6_col19 {
#   background-color: #e5f5b2;
#   color: #000000;
# }
# #T_046f0_row7_col1 {
#   background-color: #c0e6b5;
#   color: #000000;
# }
# #T_046f0_row7_col3 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_046f0_row7_col7 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_046f0_row7_col15 {
#   background-color: #b2e1b6;
#   color: #000000;
# }
# #T_046f0_row7_col18 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_046f0_row8_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_046f0_row8_col3 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_046f0_row8_col4 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_046f0_row8_col5 {
#   background-color: #7cccbb;
#   color: #000000;
# }
# #T_046f0_row8_col7 {
#   background-color: #6dc6be;
#   color: #000000;
# }
# #T_046f0_row8_col9 {
#   background-color: #feffd6;
#   color: #000000;
# }
# #T_046f0_row8_col10 {
#   background-color: #f2fabc;
#   color: #000000;
# }
# #T_046f0_row8_col17 {
#   background-color: #fdfed4;
#   color: #000000;
# }
# #T_046f0_row8_col18 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_046f0_row9_col8 {
#   background-color: #44b7c4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_046f0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th id="T_046f0_level0_col0" class="col_heading level0 col0" >T00</th>
#       <th id="T_046f0_level0_col1" class="col_heading level0 col1" >T01</th>
#       <th id="T_046f0_level0_col2" class="col_heading level0 col2" >T02</th>
#       <th id="T_046f0_level0_col3" class="col_heading level0 col3" >T03</th>
#       <th id="T_046f0_level0_col4" class="col_heading level0 col4" >T04</th>
#       <th id="T_046f0_level0_col5" class="col_heading level0 col5" >T05</th>
#       <th id="T_046f0_level0_col6" class="col_heading level0 col6" >T06</th>
#       <th id="T_046f0_level0_col7" class="col_heading level0 col7" >T07</th>
#       <th id="T_046f0_level0_col8" class="col_heading level0 col8" >T08</th>
#       <th id="T_046f0_level0_col9" class="col_heading level0 col9" >T09</th>
#       <th id="T_046f0_level0_col10" class="col_heading level0 col10" >T10</th>
#       <th id="T_046f0_level0_col11" class="col_heading level0 col11" >T11</th>
#       <th id="T_046f0_level0_col12" class="col_heading level0 col12" >T12</th>
#       <th id="T_046f0_level0_col13" class="col_heading level0 col13" >T13</th>
#       <th id="T_046f0_level0_col14" class="col_heading level0 col14" >T14</th>
#       <th id="T_046f0_level0_col15" class="col_heading level0

# %%
## Topics

TOPICS_chap = PHI_chap.stack().groupby('topic_id')\
    .apply(lambda x: ' '.join(x.sort_values(ascending=False).head(n_words).reset_index().term_str))\
    .to_frame('top_terms')

# %%
TOPICS_chap.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b932">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b932_level0_col0" class="col_heading level0 col0" >top_terms</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b932_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_4b932_row0_col0" class="data row0 col0" >lady time house way birthday man father</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row1" class="row_heading level0 row1" >T01</th>
#       <td id="T_4b932_row1_col0" class="data row1 col0" >man time room yes way door sir</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row2" class="row_heading level0 row2" >T02</th>
#       <td id="T_4b932_row2_col0" class="data row2 col0" >sea rocks time day man way letter</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row3" class="row_heading level0 row3" >T03</th>
#       <td id="T_4b932_row3_col0" class="data row3 col0" >night time door room way day things</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row4" class="row_heading level0 row4" >T04</th>
#       <td id="T_4b932_row4_col0" class="data row4 col0" >man heart creator rage creature brother companion</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row5" class="row_heading level0 row5" >T05</th>
#       <td id="T_4b932_row5_col0" class="data row5 col0" >heart eyes time hand moment night voice</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row6" class="row_heading level0 row6" >T06</th>
#       <td id="T_4b932_row6_col0" class="data row6 col0" >body corpse evidence murder river period water</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row7" class="row_heading level0 row7" >T07</th>
#       <td id="T_4b932_row7_col0" class="data row7 col0" >time house way room man day mind</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row8" class="row_heading level0 row8" >T08</th>
#       <td id="T_4b932_row8_col0" class="data row8 col0" >voice house door head room man words</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row9" class="row_heading level0 row9" >T09</th>
#       <td id="T_4b932_row9_col0" class="data row9 col0" >moor man night hound death house eyes</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row10" class="row_heading level0 row10" >T10</th>
#       <td id="T_4b932_row10_col0" class="data row10 col0" >room time hand house night opium case</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row11" class="row_heading level0 row11" >T11</th>
#       <td id="T_4b932_row11_col0" class="data row11 col0" >son man castle father thou lord youth</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row12" class="row_heading level0 row12" >T12</th>
#       <td id="T_4b932_row12_col0" class="data row12 col0" >ebony panes prince clock carpet princes mask</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row13" class="row_heading level0 row13" >T13</th>
#       <td id="T_4b932_row13_col0" class="data row13 col0" >tm work works terms agreement donations copyright</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row14" class="row_heading level0 row14" >T14</th>
#       <td id="T_4b932_row14_col0" class="data row14 col0" >men time party way light night man</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row15" class="row_heading level0 row15" >T15</th>
#       <td id="T_4b932_row15_col0" class="data row15 col0" >man hand time face day night room</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row16" class="row_heading level0 row16" >T16</th>
#       <td id="T_4b932_row16_col0" class="data row16 col0" >room door bed chamber rooms lamp apartment</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row17" class="row_heading level0 row17" >T17</th>
#       <td id="T_4b932_row17_col0" class="data row17 col0" >castle night mind chamber door voice room</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row18" class="row_heading level0 row18" >T18</th>
#       <td id="T_4b932_row18_col0" class="data row18 col0" >man time father brother day men way</td>
#     </tr>
#     <tr>
#       <th id="T_4b932_level0_row19" class="row_heading level0 row19" >T19</th>
#       <td id="T_4b932_row19_col0" class="data row19 col0" >chateau mind tears woods evening heart countenance</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Questions

# %% [markdown]
# #### 1. Use the PHI table from each model to compute the entropy H of the distribution over topics. Which bag generates a lower entropy distribution? Hint: To get H work with the L1 normalized vector of word weight sums by topic in the PHI table.

# %% [markdown]
# #### 2. Sort the topics in each model's PHI table by topic entropy in descending order. Are the first topics in the two models about the same? In other words, do they yield similar interpretations?

# %% [markdown]
# #### 3. What topic from each model is most strongly associated with each genre? Note that your answer have four parts.

# %% [markdown]
# #### 4. Using the THETA table from the Chapters model, get the mean topic weights for each book. Which book is most strongly associated with the gothic genre g, based on the weight of that genre's most representative topic (as discovered in the previous question)?

# %% [markdown]
# #### 5. How would you characterize the subject matter of the two genres based on their topic models? Consider the words associated with the dominant topics from each model, but also the models overall.
