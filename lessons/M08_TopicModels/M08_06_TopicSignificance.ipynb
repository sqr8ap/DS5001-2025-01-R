# %% [markdown]
# # Topic Term Significance
#
# DS 5001 Text as Data

# %% [markdown]
# **Purpose:** To explore term significance within topics as defined by various authors.

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
import configparser
config = configparser.ConfigParser()
config.read('../../../env.ini')
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import plotly_express as px

# %%
pd.set_option('display.max_colwidth', None)

# %%
import sys; sys.path.append(local_lib)
from hac2 import HAC

# %%
data_prefix = 'austen-melville'
colors = "YlGnBu"
n_topics = 40
OHCO = ['book_id','chap_id']

# %% [markdown]
# # Get the Data

# %%
TOPICS = pd.read_csv(f"{output_dir}/{data_prefix}-LDA_TOPICS-{n_topics}.csv").set_index('topic_id')
PHI = pd.read_csv(f"{output_dir}/{data_prefix}-LDA_PHI-{n_topics}.csv").set_index('topic_id')
THETA = pd.read_csv(f"{output_dir}/{data_prefix}-LDA_THETA-{n_topics}.csv").set_index(OHCO)

# %% [markdown]
# # Define Label Function

# %%
LABELS = pd.DataFrame({'default':None}, index=PHI.index)
def extract_label(phi, label, n_terms=7):
    LABELS[label] = LABELS.apply(lambda x: ', '.join(phi.loc[x.name].sort_values(ascending=False).head(n_terms).index), axis=1)

# %% [markdown]
# # Default

# %%
extract_label(PHI, 'default')

# %% [markdown]
# # Relevance
#
# Sievert, Carson, and Kenneth Shirley. 2014. “LDAvis: A Method for Visualizing and Interpreting Topics.” In _Proceedings of the Workshop on Interactive Language Learning, Visualization, and Interfaces_, 63–70. https://aclanthology.org/W14-3110.pdf
#
# ![image-3.png](images/topic-relevance.png)

# %%
λ = .5
PW = PHI.sum() / PHI.sum().sum()
PHI_REL = λ * np.log(PHI) + (1 - λ) * np.log(PHI/PW)

# %%
extract_label(PHI_REL, 'rel')

# %% [markdown]
# # Saliency
#
# Chuang, Jason, Christopher D. Manning, and Jeffrey Heer. 2012. “Termite: Visualization Techniques for Assessing Textual Topic Models.” In _Proceedings of the International Working Conference on Advanced Visual Interfaces_, 74–77. AVI ’12. New York, NY, USA: Association for Computing Machinery. https://doi.org/10.1145/2254556.2254572.

# %% [markdown]
# <img src="images/topic-distinctiveness-formula.png" height=5 width=450>
# <img src="images/topic-saliency-formula.png" height=5 width=450>

# %% [markdown]
# So, distinctiveness dampens local probability $P(T]w)$ with a global value $P(T)$.

# %%
PTw = (PHI / PHI.sum()).T
PT = (PHI.T.sum() / PHI.T.sum().sum())
PHI_DST = PTw * np.log(PTw/PT)
PHI_SAL = PHI_DST.T * PW

# %%
extract_label(PHI_SAL, 'sal')

# %% [markdown]
# # TFIDF
#
# We treat topics as documents.

# %%
TF = (PHI.T / PHI.T.sum()).T
DF = TF[TF > 0.00025].fillna(0).astype(bool).sum()
PHI_TFIDF = TF * np.log2((len(TF) + 1)/(DF + 1) + 1)

# %%
extract_label(PHI_TFIDF, 'tfidf')

# %% [markdown]
# # Compare

# %%
LABELS.join(TOPICS.doc_weight_sum).sort_values('doc_weight_sum', ascending=False)
# Out:
#                                                           default  \
# topic_id
# T23           time, letter, sister, feelings, heart, mind, family
# T28                         priest, canoe, maiden, yillah, whiteness, tent, devils
# T04                   jacket, freind, tho, philosophy, misfortunes, disciple, loan
# T25                      walk, horse, lane, housekeeper, time year, exercise, park
# T08                          blade, vault, crown, sleeve, garments, tail, elephant
# T20                           item, crimson, issue, neighbor, yillah, gold, islets
# T17                      merchant, fiction, characters, readers, exile, tour, text
# T37                          skeleton, skull, spine, ribs, magnitude, bulk, barrel
# T14                           ravine, roots, precipice, rock, shelter, ugh, stream
# T21                               brigantine, beer, ale, spouse, dish, cheer, beef
# T22                         portrait, picture, reign, father, coffin, origin, buoy
# T39                      knight, soldiers, officers, bonnet, lady, marines, corpse
# T10                                pounds, wife, sisters, sum, debts, linen, years
# T19                  images, hammock, cutlass, keg, brigantine, trembling, rigging
# T34              carpenter, coffin, stone, significance, extremities, vice, coward
# T11                     apples, romance, fiction, doctor, planters, library, apple
# T35                               mess, shrine, cook, butter, cooks, breach, rites
# T12                                  paper, ink, gunner, powder, hath, thee, bread
# T30                      lashes, punishment, cat, fleet, dozen, flogging, squadron
# T29       quadrant, log, instruments, chronometer, instrument, purposes, forthwith
#
#                                                                         sal  \
# topic_id
# T23        letter, feelings, sister, happiness, family, affection, marriage
# T15                        room, oh, evening, thing, friend, dear, pleasure
# T32                              deck, men, ship, mate, sailors, man, board
# T31                              sea, water, wind, air, breeze, land, waves
# T01                           lord, gods, things, mortals, isle, god, yoomy
# T05               valley, natives, islanders, fruit, island, trees, savages
# T18           man, stranger, cosmopolitan, friend, gentleman, sort, charity
# T36                            whale, whales, boat, boats, fish, ship, head
# T00                              room, house, door, bed, night, hour, hours
# T02                              sir, thou, thee, boy, brother, barber, art
# T13                        book, captain, sailors, boy, docks, dock, sailor
# T27              gentlemen, negroes, deponent, negro, servant, ship, blacks
# T26                       man, world, herb, nature, soul, herb doctor, book
# T07                                    ye, leg, aye, thou, ivory, ha, thats
# T09                 house, country, ladies, place, church, music, residence
# T03                        ha, image, child, wine, driver, guests, tomahawk
# T38               king, kings, island, royal, missionaries, people, monarch
# T33                        mother, guitar, love, thee, woman, puff, mothers
# T16                         doctor, ugh, cook, court, island, round, sailor
# T24                         man, beard, law, beards, officers, barbers, war
# T06          consul, emigrants, steerage, passengers, chests, idols, doctor
# T28                  canoe, priest, maiden, yillah, devils, whiteness, soul
# T04               jacket, philosophy, tho, freind, boots, misfortunes, loan
# T25                 walk, horse, house, weather, lane, housekeeper, country
# T08                            blade, crown, vault, tail, coat, feet, tails
# T20                    crimson, item, gold, issue, neighbor, yillah, groves
# T17       merchant, characters, character, fiction, readers, years, streets
# T37                     skeleton, skull, feet, spine, ribs, magnitude, bulk
# T14                       rock, roots, ravine, stream, feet, ugh, precipice
# T21                       brigantine, beer, ale, beef, sailors, dish, cheer
# T22               portrait, father, picture, reign, fathers, coffin, origin
# T39                  officers, lady, knight, soldiers, bonnet, thou, corpse
# T10                  pounds, wife, father, years, sisters, mother, children
# T19               hammock, vessel, images, rigging, craft, ship, brigantine
# T34              carpenter, coffin, stone, end, vice, significance, hammock
# T11           doctor, apples, romance, fiction, library, planters, calabash
# T35                         mess, cook, shrine, butter, cooks, breach, beef
# T12                             paper, thee, thou, bread, hath, powder, ink
# T30                 punishment, lashes, cat, fleet, dozen, powder, squadron
# T29            log, quadrant, instruments, instrument, purposes, cabin, sea
#
#                                                                       tfidf  \
# topic_id
# T23          sister, letter, feelings, happiness, affection, time, marriage
# T15                             room, sister, oh, dear, thing, time, friend
# T32                            deck, ship, man, men, mate, frigate, sailors
# T31                                 sea, wind, boat, water, ship, land, air
# T01                               lord, gods, man, things, isle, men, yoomy
# T05               natives, valley, islanders, island, savages, fruit, trees
# T18          man, cosmopolitan, friend, stranger, confidence, sort, charity
# T36                      whale, whales, boat, boats, ship, fish, harpooneer
# T00                              room, house, door, bed, night, time, hours
# T02                              sir, thou, thee, boy, barber, brother, man
# T13                        captain, book, sailors, docks, dock, boy, sailor
# T27                 deponent, ship, man, negroes, gentlemen, negro, servant
# T26                 man, herb, herb doctor, confidence, world, nature, soul
# T07                                      ye, leg, aye, thou, ivory, ha, man
# T09                    house, ladies, country, church, cottage, place, park
# T03                      ha, child, aunt, painting, image, driver, tomahawk
# T38                 king, kings, missionaries, island, monarch, royal, glen
# T33                        mother, guitar, thee, love, woman, mothers, puff
# T16                             doctor, ugh, cook, court, island, boat, dat
# T24                      man, officers, beards, barbers, beard, law, seamen
# T06          consul, steerage, emigrants, passengers, idols, chests, doctor
# T28                  canoe, priest, maiden, yillah, whiteness, devils, tent
# T04               jacket, philosophy, freind, tho, misfortunes, boots, loan
# T25                    walk, aunt, horse, house, housekeeper, weather, park
# T08                           vault, blade, crown, tail, feet, sleeve, coat
# T20                     item, crimson, yillah, issue, neighbor, gold, goods
# T17       merchant, characters, character, fiction, readers, streets, years
# T37                   skeleton, whale, whales, skull, feet, ribs, magnitude
# T14                         ravine, rock, ugh, roots, stream, feet, shelter
# T21                       brigantine, ale, beer, ship, sailors, ships, dish
# T22               portrait, father, picture, reign, coffin, fathers, origin
# T39                     officers, lady, knight, soldiers, thou, sir, bonnet
# T10                  sisters, pounds, mother, father, wife, years, children
# T19                     ship, rigging, vessel, craft, hammock, oars, images
# T34                      carpenter, coffin, stone, vice, end, navy, hammock
# T11           doctor, apples, romance, library, fiction, calabash, planters
# T35                         mess, cook, cooks, shrine, butter, breach, beef
# T12                             thee, paper, thou, hath, bread, powder, ink
# T30               punishment, lashes, cat, dozen, fleet, flogging, squadron
# T29         log, quadrant, instruments, sea, instrument, cabin, chronometer
#
#           doc_weight_sum
# topic_id
# T23           163.569493
# T15           140.340735
# T32            94.888590
# T31            76.190798
# T01            72.288680
# T05            52.151496
# T18            45.478509
# T36            45.423579
# T00            40.273350
# T02            35.694933
# T13            34.749942
# T27            28.242731
# T26            28.224108
# T07            23.945168
# T09            23.443175
# T03            19.503756
# T38            17.874896
# T33            16.385630
# T16            16.195809
# T24            15.341834
# T06            14.455065
# T28            13.795738
# T04            12.717129
# T25            12.625599
# T08            12.528364
# T20            11.299459
# T17            10.344668
# T37             9.789925
# T14             9.785326
# T21             9.238863
# T22             8.610359
# T39             8.537125
# T10             8.151771
# T19             7.641651
# T34             7.466790
# T11             6.519059
# T35             5.831436
# T12             4.865190
# T30             4.572380
# T29             4.016888
